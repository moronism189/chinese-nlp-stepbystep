# %% [markdown]
# ## `中文的分词和文档的数字表示`

# %% [markdown]
# 要让电脑或是任何NLP 模型理解一篇新闻标题在说什么，我们不能将自己已经非常习惯的语言文字直接扔给电脑，而是要转换成它熟悉的形式：数字。
#
# ### 中文的分词
#
# 这里我们将一篇新闻标题视为一个“文档”，在中文的语言特征里，文档的基本单位主要由词构成。不同于英文的是，中文句子中没有词的界限，因此进行中文文档的数字表示时，通常需要先做分词以及词的编码。
# 常见的基于中文分词算法有：正向最大匹配法、逆向最大匹配法、双向匹配法、最优匹配法、联想-回溯法等。
#
# 借助 **Jieba** 这个中文分词工具，可以轻松实现中文的分词。

# %%
import jieba.posseg as pseg   

text = '一片大蒜轻松鉴别地沟油'  
words = pseg . cut ( text ) 
[ word for word in words ]
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\HP\AppData\Local\Temp\jieba.cache
# Loading model cost 0.677 seconds.
# Prefix dict has been built successfully.
# [pair('一片', 'm'),
#  pair('大蒜', 'n'),
#  pair('轻松', 'a'),
#  pair('鉴别', 'v'),
#  pair('地沟油', 'n')]

# %%
TRAIN_CSV_PATH = "./train.csv" 
import pandas as pd 
train = pd . read_csv ( TRAIN_CSV_PATH , index_col = 0 ) 
cols = [ 'title1_zh' , 'title2_zh' , 'label' ] 
train = train . loc [:, cols ]

# %%
train_nan = train[train[['title1_zh','title2_zh']].isnull().any(axis=1)] #训练集空值检查 
train_nan['title2_zh'].apply(lambda x: pd.isna(x))
# Out:
# id
# 48473     True
# 64312     True
# 220922    True
# 243368    True
# 247695    True
# 259536    True
# 291779    True
# Name: title2_zh, dtype: bool

# %% [markdown]
# 我们可以利用 **Pandas** 的 **apply** 函数，将一个自定义的函数 **jieba_tokenizer** 套用到所有新闻标题A 以及B 之上，做文本分词：

# %%
def jieba_tokenizer ( text ): 
     if not(pd.isna(text)): 
            words = pseg . cut ( text ) 
            return ' ' . join ([ word for word , flag in words if flag != 'x' ]) ##标点符号去除 
     return ' ' 

train [ 'title1_tokenized' ] = \
     train . loc [:, 'title1_zh' ] \
          . apply ( jieba_tokenizer ) 
train [ 'title2_tokenized' ] = \
     train . loc [:, 'title2_zh' ] \
          . apply ( jieba_tokenizer )

# %% [markdown]
# 分词过程出乎意料的漫长，我们用 **pickle** 把结果持久化保存下来，以便之后可以继续快速使用。

# %%
import pickle 
 
pkl_file = open('./save_file', 'wb') 
pickle.dump(train,pkl_file,pickle.HIGHEST_PROTOCOL) 
pkl_file.close() 
 
pkl_file_rb = open(r'./save_file', 'rb') 
new_data =pickle.load(pkl_file_rb) 
new_data.head(2)
# Out:
#                             title1_zh                  title2_zh      label  \
# id
# 0       2017养老保险又新增两项，农村老人人人可申领，你领到了吗   警方辟谣“鸟巢大会每人领5万” 仍有老人坚持进京  unrelated
# 3   "你不来深圳，早晚你儿子也要来"，不出10年深圳人均GDP将超香港  深圳GDP首超香港？深圳统计局辟谣：只是差距在缩小  unrelated
#
#                                    title1_tokenized  \
# id
# 0          2017 养老保险 又 新增 两项 农村 老人 人人 可 申领 你 领到 了 吗
# 3   你 不 来 深圳 早晚 你 儿子 也 要 来 不出 10 年 深圳 人均 GDP 将 超 香港
#
#                       title2_tokenized
# id
# 0    警方 辟谣 鸟巢 大会 每人 领 5 万 仍 有 老人 坚持 进京
# 3   深圳 GDP 首 超 香港 深圳 统计局 辟谣 只是 差距 在 缩小

# %% [markdown]
# ---
# 下面一段内容我们先从李孟博士的博客里绕开，尝试一些更为简洁的NLP方法。
#
# ### TF-IDF文档向量表示
#
# 完成分词之后，就可以进行文档的数字化表示。
# 可用的方法有很多，我们首先从常用的 TF-IDF文档向量表示方法入手。TF-IDF是一种向量空间模型（VSM：Vector Space Model），VSM中每个文档d可以用词典标引项向量来表示V(d)=(W1,W2,...Wm)，Wi对应第i个标引词的权重。
# VSM中权重的计算有：布尔权重（下图中的示例，仅标识文档中是否包含某词）、词频权重、TF-IDF权重、熵权重等，其中最广泛采用的便是TF-IDF权重。
#
# ![这是图片](imgs/photo1.jpg "bool-weight")
#
# TF-IDF的主要思想是，如果某个词或短语在一篇文章中出现的频率TF高，并且在其他文章中很少出现，则认为此词或者短语具有很好的类别区分能力，适合用来分类。
#     TF词频(Term Frequency)指的是某一个给定的词语在该文件中出现的次数。
#     IDF逆文档频率(Inverse Document Frequency)的主要思想是：如果包含词条的文档越少，IDF越大，则说明词条具有很好的类别区分能力。
#       将TF和IDF相乘，形成TF-IDF度量：TF-IDF（d,t）= TF(d,t) * IDF(t) 。
#
# 我们可以使用 **sklearn** 包中的 **TfidfVectorizer** 函数实现文档的TF-IDF向量化表示。

# %%
from sklearn.feature_extraction.text import TfidfVectorizer 
 
corpus = pd.concat([train . title1_tokenized, train . title2_tokenized]) 
corpus = [c for c in corpus] 
corpus
# Out:
# ['2017 养老保险 又 新增 两项 农村 老人 人人 可 申领 你 领到 了 吗',
#  '你 不 来 深圳 早晚 你 儿子 也 要 来 不出 10 年 深圳 人均 GDP 将 超 香港',
#  '你 不 来 深圳 早晚 你 儿子 也 要 来 不出 10 年 深圳 人均 GDP 将 超 香港',
#  '你 不 来 深圳 早晚 你 儿子 也 要 来 不出 10 年 深圳 人均 GDP 将 超 香港',
#  '用 大蒜 鉴别 地沟油 的 方法 怎么 鉴别 地沟油',
#  '你 不 来 深圳 早晚 你 儿子 也 要 来 不出 10 年 深圳 人均 GDP 将 超 香港',
#  '吃 榴莲 的 禁忌 吃 错会 致命',
#  '你 不 来 深圳 早晚 你 儿子 也 要 来 不出 10 年 深圳 人均 GDP 将 超 香港',
#  '旅行 青蛙 居然 是 一款 生育 意愿 测试 器 大家 还是 玩 珠宝 V 课 吧',
#  '用 大蒜 鉴别 地沟油 的 方法 怎么 鉴别 地沟油',
#  '用 大蒜 鉴别 地沟油 的 方法 怎么 鉴别 地沟油',
#  '用 大蒜 鉴别 地沟油 的 方法 怎么 鉴别 地沟油',
#  '用 大蒜 鉴别 地沟油 的 方法 怎么 鉴别 地沟油',
#  '用 大蒜 鉴别 地沟油 的 方法 怎么 鉴别 地沟油',
#  '飞机 就要 起飞 一个 男人 在 机舱 口 跪下 这 是 今天 最 催泪 的 一幕',
#  '飞机 就要 起飞 一个 男人 在 机舱 口 跪下 这 是 最 催泪 的 一幕',
#  '男人 在 机舱 口 跪下 原来 一切 都 只 因为 爱',
#  '飞机 就要 起飞 一个 男人 在 机舱 口 跪下 这 是 今天 最 催泪 的 一幕',
#  '飞机 就要 起飞 一个 男人 在 机舱 口 跪下 这 是 见 过 最 催泪 的 一幕',
#  '健康 过大年 还 在 逗 孩子 喝酒 儿童 喝酒 的 危害 多 大 你 知道 吗',
#  '健康 过大年 还 在 逗 孩子 喝酒 儿童 喝酒 的 危害 多 大 你 知道 吗',
#  '健康 过大年 还 在 逗 孩子 喝酒 儿童 喝酒 的 危害 多 大 你 知道 吗',
#  '农民 铜川市 耀州区 农民 每亩 地 补助 多少 钱',
#  '农民 铜川市 耀州区 农民 每亩 地 补助 多少 钱',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '吃秀 美好 的 一天 从 早餐 开始 续集 这 会 灯 好多 上 个 一会 黑 一会 白 本来 皮肤 就 黄',
#  '旅行 化妆包 专 治疗 颈椎病 腰间盘 突出 中药 泡酒 喝',
#  '旅行 化妆包 专 治疗 颈椎病 腰间盘 突出 中药 泡酒 喝',
#  '旅行 化妆包 专 治疗 颈椎病 腰间盘 突出 中药 泡酒 喝',
#  '旅行 化妆包 专 治疗 颈椎病 腰间盘 突出 中药 泡酒 喝',
#  '旅行 化妆包 专 治疗 颈椎病 腰间盘 突出 中药 泡酒 喝',
#  '爱自拍 影响 智商 我 说 类 怎么 越来越 聪明 了',
#  '爱自拍 影响 智商 我 说 类 怎么 越来越 聪明 了',
#  '爱自拍 影响 智商 我 说 类 怎么 越来越 聪明 了',
#  '爱自拍 影响 智商 我 说 类 怎么 越来越 聪明 了',
#  '秋 补 啤酒肚 和 喝啤酒 有 关系 吗',
#  '爱自拍 影响 智商 我 说 类 怎么 越来越 聪明 了',
#  '爱自拍 影响 智商 我 说 类 怎么 越来越 聪明 了',
#  '秋 补 菠菜 能 补铁 补血 吗',
#  '秋 补 啤酒肚 和 喝啤酒 有 关系 吗',
#  '爱自拍 影响 智商 我 说 类 怎么 越来越 聪明 了',
#  '秋 补 菠菜 能 补铁 补血 吗',
#  '花式 新 吃法 苦瓜 和 香蕉 最 减肥 的 做法 头条 美食 楠哥 说 事',
#  '萌 了 个 萌 专 治疗 颈椎病 腰间盘 突出 中药 泡酒 喝',
#  '营养 美食 季 糖尿病人 到底 能 不能 吃 土豆',
#  '营养 美食 季 糖尿病人 到底 能 不能 吃 土豆',
#  '营养 美食 季 糖尿病人 到底 能 不能 吃 土豆',
#  '谁 也 挡不住 你 的 微笑 专 治疗 颈椎病 腰间盘 突出 中药 泡酒 喝',
#  '毛钱 的 特效 2014 浙江 手机 实拍 UFO 不明飞行物',
#  '谁 也 挡不住 你 的 微笑 专 治疗 颈椎病 腰间盘 突出 中药 泡酒 喝',
#  '毛钱 的 特效 2014 浙江 手机 实拍 UFO 不明飞行物',
#  '毛钱 的 特效 2014 浙江 手机 实拍 UFO 不明飞行物',
#  'ST 碳 A股 沉浮 25 年 从 深市 东北 第一股 到 非标 退市 第一股',
#  'ST 碳 A股 沉浮 25 年 从 深市 东北 第一股 到 非标 退市 第一股',
#  'ST 碳 A股 沉浮 25 年 从 深市 东北 第一股 到 非标 退市 第一股',
#  '.. 陆地 夫妇 上演 真实 我们 相爱 吧',
#  '.. 陆地 夫妇 上演 真实 我们 相爱 吧',
#  '果粒 橙 含有 美国 禁用 农药 多菌灵',
#  '.. 陆地 夫妇 上演 真实 我们 相爱 吧',
#  '.. 陆地 夫妇 上演 真实 我们 相爱 吧',
#  '.. 陆地 夫妇 上演 真实 我们 相爱 吧',
#  '.. 陆地 夫妇 上演 真实 我们 相爱 吧',
#  '.1959 年 冷战 时期 俄罗斯 秘密 部队 在 研究 捕获 的 外星人',
#  '不可 与 柿子 同 食 吃 鸡蛋 有 哪些 禁忌',
#  '不可 与 柿子 同 食 吃 鸡蛋 有 哪些 禁忌',
#  '不可 与 柿子 同 食 吃 鸡蛋 有 哪些 禁忌',
#  '不可 与 柿子 同 食 吃 鸡蛋 有 哪些 禁忌',
#  '. 据 美国 科学家 研究 男人 每 7 秒 就 会 有 一次性 冲动',
#  '. 据 美国 科学家 研究 男人 每 7 秒 就 会 有 一次性 冲动',
#  '. 据 美国 科学家 研究 男人 每 7 秒 就 会 有 一次性 冲动',
#  '. 据 美国 科学家 研究 男人 每 7 秒 就 会 有 一次性 冲动',
#  '. 据 美国 科学家 研究 男人 每 7 秒 就 会 有 一次性 冲动',
#  '支付宝 这样 提现 可以 永久 免费 那微信 要 怎么办',
#  '. 据 美国 科学家 研究 男人 每 7 秒 就 会 有 一次性 冲动',
#  '支付宝 这样 提现 可以 永久 免费 那微信 要 怎么办',
#  '支付宝 这样 提现 可以 永久 免费 那微信 要 怎么办',
#  '. 据 美国 科学家 研究 男人 每 7 秒 就 会 有 一次性 冲动',
#  '英国 多个 实验室 在 过去 三年 中 秘密 实验 人兽 杂交',
#  '支付宝 这样 提现 可以 永久 免费 那微信 要 怎么办',
#  '英国 多个 实验室 在 过去 三年 中 秘密 实验 人兽 杂交',
#  '英国 多个 实验室 在 过去 三年 中 秘密 实验 人兽 杂交',
#  '英国 多个 实验室 在 过去 三年 中 秘密 实验 人兽 杂交',
#  '英国 多个 实验室 在 过去 三年 中 秘密 实验 人兽 杂交',
#  '英国 多个 实验室 在 过去 三年 中 秘密 实验 人兽 杂交',
#  '英国 多个 实验室 在 过去 三年 中 秘密 实验 人兽 杂交',
#  '这次 日本 又 眼红 了 中国 广西 发现 这 一 重要 资源 可 开采 足足 100 年',
#  '这次 日本 又 眼红 了 中国 广西 发现 这 一 重要 资源 可 开采 足足 100 年',
#  '这次 日本 又 眼红 了 中国 广西 发现 这 一 重要 资源 可 开采 足足 100 年',
#  '英国 多个 实验室 在 过去 三年 中 秘密 实验 人兽 杂交',
#  '002 国产 航母 冒 黑烟 是 动力 问题 专家 称 肚子 和 俄 航母 截然不同',
#  '002 航母 即将 海试 美国 却 劝告 中国 放弃 造 航母 同时 这事 让 人 愤怒',
#  '002 航母 即将 海试 美国 却 劝告 中国 放弃 造 航母 同时 这事 让 人 愤怒',
#  '002 航母 即将 海试 美国 却 劝告 中国 放弃 造 航母 同时 这事 让 人 愤怒',
#  '003 核动力 航母 已 开建 排水量 11 万吨 载机 70 架 直接 超越 美国 福 特级',
#  '003 核动力 航母 已 开建 排水量 11 万吨 载机 70 架 直接 超越 美国 福 特级',
#  '003 核动力 航母 已 开建 排水量 11 万吨 载机 70 架 直接 超越 美国 福 特级',
#  '003 核动力 航母 已 开建 排水量 11 万吨 载机 70 架 直接 超越 美国 福 特级',
#  '003 核动力 航母 已 开建 排水量 11 万吨 载机 70 架 直接 超越 美国 福 特级',
#  '003 核动力 航母 已 开建 排水量 11 万吨 载机 70 架 直接 超越 美国 福 特级',
#  '003 核动力 航母 已 开建 排水量 11 万吨 载机 70 架 直接 超越 美国 福 特级',
#  '003 核动力 航母 已 开建 排水量 11 万吨 载机 70 架 直接 超越 美国 福 特级',
#  '003 核动力 航母 已 开建 排水量 11 万吨 载机 70 架 直接 超越 美国 福 特级',
#  '003 核动力 航母 已 开建 排水量 11 万吨 载机 70 架 将 比肩 福 特级',
#  '003 核动力 航母 已 开建 排水量 11 万吨 载机 70 架 将 比肩 福 特级',
#  '003 核动力 航母 已 开建 排水量 11 万吨 载机 70 架 将 比肩 福 特级',
#  '003 核动力 航母 开建 排水量 11 万吨 载机 70 架 超 美国 福 特级',
#  '003 核动力 航母 开建 排水量 11 万吨 载机 70 架 超 美国 福 特级',
#  '003 核动力 航母 开建 排水量 11 万吨 载机 70 架 超 美国 福 特级',
#  '003 核动力 航母 已 开建 排水量 11 万吨 载机 70 架 将 比肩 福 特级',
#  '003 核动力 航母 开建 排水量 11 万吨 载机 70 架 超 美国 福 特级',
#  '003 核动力 航母 开建 排水量 11 万吨 载机 70 架 超 美国 福 特级',
#  '003 核动力 航母 开建 排水量 11 万吨 载机 70 架 超 美国 福 特级',
#  '00 后 CEO 喻言 吐 槽 成年人 拿 着 基本工资 打着 王者 荣耀 妈 的 扎心 了',
#  '0096 方便面 吃 多 了 会 变 木乃伊',
#  '00 后 CEO 喻言 吐 槽 成年人 拿 着 基本工资 打着 王者 荣耀 妈 的 扎心 了',
#  '0096 方便面 吃 多 了 会 变 木乃伊',
#  '00 后 CEO 喻言 在 放学 别 走 舞台 上 吐 槽 成年人 拿 死 工资 打 农药',
#  '00 后 CEO 喻言 狂 怼 成年人 平庸',
#  '00 后 CEO 喻言 在 放学 别 走 舞台 上 吐 槽 成年人 拿 死 工资 打 农药',
#  '00 后 CEO 狂 怼 成年人',
#  '00 后 美女 CEO 狂 怼 成年人 湖南卫视 或 成 幕后 推手',
#  '00 后 CEO 狂 怼 成年人',
#  '00 后 CEO 狂 怼 成年人',
#  '00 后 美女 CEO 狂 怼 成年人 湖南卫视 或 成 幕后 推手',
#  '00 后 都 已当 CEO 了 这位 16 岁 CEO 怒 怼 成年人 拿 死 工资 还 在 打游戏',
#  '00 后 美女 CEO 狂 怼 成年人 湖南卫视 或 成 幕后 推手',
#  '00 后 都 已当 CEO 了 这位 16 岁 CEO 怒 怼 成年人 拿 死 工资 还 在 打游戏',
#  '00 后 都 已当 CEO 了 这位 16 岁 CEO 怒 怼 成年人 拿 死 工资 还 在 打游戏',
#  '00 后 都 已当 CEO 了 这位 16 岁 CEO 怒 怼 成年人 拿 死 工资 还 在 打游戏',
#  '00 后 都 已当 CEO 了 这位 16 岁 CEO 怒 怼 成年人 拿 死 工资 还 在 打游戏',
#  '00 后 都 已当 CEO 了 这位 16 岁 CEO 怒 怼 成年人 拿 死 工资 还 在 打游戏',
#  '00 岁 的 CEOdiss 成年人 拿 着 死 工资 打 王者 荣耀 这 日子 没法 过 了',
#  '053 期 小孩 发烧 怎么 降温 花 一分钟 学会 妙 招 再也 不用 去 药店 了',
#  '00 后 都 已当 CEO 了 这位 16 岁 CEO 怒 怼 成年人 拿 死 工资 还 在 打游戏',
#  '00 后 美女 CEO 狂 怼 成年人 湖南卫视 或 成 幕后 推手',
#  '053 期 小孩 发烧 怎么 降温 花 一分钟 学会 妙 招 再也 不用 去 药店 了',
#  '056 期 常 吃 这五种 食物 等于 再 慢性 自杀',
#  '068 喝 豆浆 丰胸',
#  '068 喝 豆浆 丰胸',
#  '05 版 的 尾号 为 66666 的 100 元 和 10 元 豹子 号 人民币 具有 收藏 价值',
#  '05 版 的 尾号 为 66666 的 100 元 和 10 元 豹子 号 人民币 具有 收藏 价值',
#  '068 喝 豆浆 丰胸',
#  '07.07 周到 晨报 出生 月份 竟 能 决定 你 易得 哪种 病 这 是 真的 这个 月 出生 的 人 最 健康',
#  '07.07 周到 晨报 出生 月份 竟 能 决定 你 易得 哪种 病 这 是 真的 这个 月 出生 的 人 最 健康',
#  '07.07 周到 晨报 出生 月份 竟 能 决定 你 易得 哪种 病 这 是 真的 这个 月 出生 的 人 最 健康',
#  '07.07 周到 晨报 出生 月份 竟 能 决定 你 易得 哪种 病 这 是 真的 这个 月 出生 的 人 最 健康',
#  '07.07 周到 晨报 出生 月份 竟 能 决定 你 易得 哪种 病 这 是 真的 这个 月 出生 的 人 最 健康',
#  '07.07 周到 晨报 出生 月份 竟 能 决定 你 易得 哪种 病 这 是 真的 这个 月 出生 的 人 最 健康',
#  '07.07 周到 晨报 出生 月份 竟 能 决定 你 易得 哪种 病 这 是 真的 这个 月 出生 的 人 最 健康',
#  '07 年 快乐 男生 陈楚生 圆满 张杰 有名气 而 他 让 人 心碎',
#  '成本 还 想 赚钱 微信群助 你 空 手套 白狼',
#  '成本 还 想 赚钱 微信群助 你 空 手套 白狼',
#  '3 岁 宝宝 发烧 用 这个 办法 不用 打针 吃药 安全 没有 副作用',
#  '3 岁 宝宝 发烧 用 这个 办法 不用 打针 吃药 安全 没有 副作用',
#  '1.2 亿 先生 无意 续约 火箭 收 渔翁之利 迎 第三 巨头 红色 王朝 将 诞生',
#  '10 月 广东 地方 财政收入 累计 增 12.9 6 个 地市 呈 负增长',
#  '1.5 万 入手 的 小赌 石 赌高 冰 玻璃 种 意外 赌出 顶级 帝王 绿',
#  '1.19 超快 顺产 男 宝宝 一枚 附 症状 喜欢 男孩 的来 接',
#  '1.5 块 小 药片 碾碎 治好 了 9 年 的 脖子 疼 头晕 手麻 1 天 见效 7 天去 根',
#  '1.5 块 小 药片 碾碎 治好 了 9 年 的 脖子 疼 头晕 手麻 1 天 见效 7 天去 根',
#  '癌症病人 中医 治疗 延长 了 寿命 癌症 康复 33',
#  '1.5 块 小 药片 碾碎 治好 了 9 年 的 脖子 疼 头晕 手麻 1 天 见效 7 天去 根',
#  '100 孕妈 怀孕 期间 离不开 的 东西 造成 孩子 畸形',
#  '100 全面 屏 有 爱 吗 小米 MIX3 背部 谍 照曝光 神似 iPhone',
#  '癌症病人 中医 治疗 延长 了 寿命 癌症 康复 33',
#  '100 孕妈 怀孕 期间 离不开 的 东西 造成 孩子 畸形',
#  '100 孕妈 怀孕 期间 离不开 的 东西 造成 孩子 畸形',
#  '100 孕妈 怀孕 期间 离不开 的 东西 造成 孩子 畸形',
#  '100 全面 屏 有 爱 吗 小米 MIX3 背部 谍 照曝光 神似 iPhone',
#  '100 孕妈 怀孕 期间 离不开 的 东西 造成 孩子 畸形',
#  '100 孕妈 怀孕 期间 离不开 的 东西 造成 孩子 畸形',
#  '100 孕妈 怀孕 期间 离不开 的 东西 造成 孩子 畸形',
#  '100 孕妈 怀孕 期间 离不开 的 东西 造成 孩子 畸形',
#  '10000 多 外地人 解剖 小孩 偷 器官',
#  '100 孕妈 怀孕 期间 离不开 的 东西 造成 孩子 畸形',
#  '10000 万 这 枚 钱币 很 值得 你 收藏',
#  '10000 万 这 枚 钱币 很 值得 你 收藏',
#  '10000 多 外地人 解剖 小孩 偷 器官',
#  '10000 多 外地人 解剖 小孩 偷 器官',
#  '1000 VS10 万 中国 球迷 赛后 遭 伊朗 球迷 四面 围攻',
#  '10000 多 外地人 解剖 小孩 偷 器官',
#  '1000 万 中国 人 在 印尼 打 黑工',
#  '10000 多 外地人 解剖 小孩 偷 器官',
#  '1000 万 中国 人 在 印尼 打 黑工',
#  '1000 人 犯罪团伙 来 德州 偷 孩子 取 器官',
#  '1000 万 中国 人 在 印尼 打 黑工',
#  '1000 元 人民币 发行',
#  '1000 人 犯罪团伙 来 德州 偷 孩子 取 器官',
#  '1000 人 犯罪团伙 来 德州 偷 孩子 取 器官',
#  '1000 人 犯罪团伙 来 德州 偷 孩子 取 器官',
#  '1000 人 犯罪团伙 来 德州 偷 孩子 取 器官',
#  '1000 人 犯罪团伙 来 德州 偷 孩子 取 器官',
#  '1000 元 人民币 发行',
#  '1000 公里 的 借水 隧洞 欲 将 沙漠 变 绿洲 中国 又 创 奇迹',
#  '1000 多张 关于 Nasa 的 原始 照片 证据 直指 月球 是 外星人 基地',
#  '1000 多张 关于 Nasa 的 原始 照片 证据 直指 月球 是 外星人 基地',
#  '1000 度 金属 球 vs 巧克力 心脏 不好 的 朋友 注意',
#  '1000 度 金属 球 vs 巧克力 心脏 不好 的 朋友 注意',
#  '100 万 十年 后 相当于 现在 的 多少 钱 答案 你 肯定 想不到 也 不 愿 接受',
#  '100 个人 里面 100 个人 都 不 知道 的 微信 聊天记录 恢复 的 办法',
#  '100 万 十年 后 相当于 现在 的 多少 钱 答案 你 肯定 想不到 也 不 愿 接受',
#  '100 万 十年 后 相当于 现在 的 多少 钱 答案 你 肯定 想不到 也 不 愿 接受',
#  '100 万 十年 后 相当于 现在 的 多少 钱 答案 你 肯定 想不到 也 不 愿 接受',
#  '100 个人 里面 100 个人 都 不 知道 的 微信 聊天记录 恢复 的 办法',
#  '100 个人 里面 100 个人 都 不 知道 的 微信 聊天记录 恢复 的 办法',
#  '100 个人 里面 100 个人 都 不 知道 的 微信 聊天记录 恢复 的 办法',
#  '100 个 月 太 夸张 那 王者 荣耀 团队 年终奖 到底 有 多少',
#  '100 个 月 太 夸张 那 王者 荣耀 团队 年终奖 到底 有 多少',
#  '100 个人 里面 100 个人 都 不 知道 的 微信 聊天记录 恢复 的 办法',
#  '100 个 月 太 夸张 那 王者 荣耀 团队 年终奖 到底 有 多少',
#  '100 位 外国 音乐 人 演奏 西游记 主题曲 万名 观众 场面 震撼',
#  '100 位 外国 音乐 人 演奏 西游记 主题曲 万名 观众 场面 震撼',
#  '100 位 外国 音乐 人 现场 演奏 86 西游记 主题曲 5 万 人 观看',
#  '100 位 外国 音乐 人 演奏 西游记 主题曲 万名 观众 场面 震撼',
#  '100 位 外国 音乐 人 演奏 西游记 主题曲 万名 观众 场面 震撼',
#  '100 元 感谢费 骗 孩子 上车 带路',
#  '100 元 感谢费 骗 孩子 上车 带路',
#  '100 元 感谢费 骗 孩子 上车 带路',
#  '100 元 感谢费 骗 孩子 上车 带路',
#  '100 元 感谢费 骗 孩子 上车 带路',
#  '100 元 感谢费 骗 孩子 上车 带路',
#  '100 元 感谢费 骗 孩子 上车 带路',
#  '100 元 感谢费 骗 孩子 上车 带路',
#  '100 元 感谢费 骗 孩子 上车 带路',
#  '100 元 感谢费 骗 孩子 上车 带路',
#  '100 元 感谢费 骗 孩子 上车 带路',
#  '100 元 纸币 都 价值 上万元 快回去 找下 说不定 你 也 有 哦',
#  '100 元 纸币 都 价值 上万元 快回去 找下 说不定 你 也 有 哦',
#  '100 元 纸币 都 价值 上万元 快回去 找下 说不定 你 也 有 哦',
#  '100 多个 外地人 到 福建省 市偷 抢 小孩',
#  '100 多个 外地人 到 福建省 市偷 抢 小孩',
#  '100 多个 外地人 到 福建省 市偷 抢 小孩',
#  '100 多个 外地人 到 福建省 市偷 抢 小孩',
#  '100 多个 外地人 到 福建省 市偷 抢 小孩',
#  '100 多个 外地人 到 福建省 市偷 抢 小孩',
#  '100 多年 前 此国 抢占 我国 领土 中国 强大 后 又 跑 归来 主动 归还',
#  '100 多个 外地人 到 福建省 市偷 抢 小孩',
#  '100 多年 前 此国 抢占 我国 领土 中国 强大 后 又 跑 归来 主动 归还',
#  '100 平方米 的 农村 屋顶 安 光伏 发电 成本 是 多少 钱 答案 万万 没想到',
#  '100 平方米 的 农村 屋顶 安 光伏 发电 成本 是 多少 钱 答案 万万 没想到',
#  '100 年 不 染发 啤酒 加 它 洗头 再 凶狠 的 白发 三分钟 黑 如 煤炭',
#  '100 年 不 染发 啤酒 加 它 洗头 再 凶狠 的 白发 三分钟 黑 如 煤炭',
#  '100 平方米 的 农村 屋顶 安 光伏 发电 成本 是 多少 钱 答案 万万 没想到',
#  '100 年前 光绪帝 在 北大 的 讲话 组图',
#  '100 平方米 的 农村 屋顶 安 光伏 发电 成本 是 多少 钱 答案 万万 没想到',
#  '100 年前 孙中山 先生 预言 中国 的 2018 年 只有 一个 没 实现',
#  '100 年后 人类 将 离开 地球 霍金的 预言 会 在 他 离开 后 变成 现实 吗',
#  '100 年后 人类 将 离开 地球 霍金的 预言 会 在 他 离开 后 变成 现实 吗',
#  '100 年 到 1 亿年 后 的 地球 会 发生 什么 日本 成为 最先 沉没 的 国家',
#  '100 年前 孙中山 先生 预言 中国 的 2018 年 只有 一个 没 实现',
#  '102 岁 老中医 膝盖 疼 秘方 流出 几片 生姜 走路 健步如飞 赶紧 存 下来',
#  '102 岁 老中医 膝盖 疼 秘方 流出 几片 生姜 走路 健步如飞 赶紧 存 下来',
#  '107 国道 养 狗场 有 几千只 狗 等待 被 领养',
#  '102 岁 老中医 膝盖 疼 秘方 流出 几片 生姜 走路 健步如飞 赶紧 存 下来',
#  '103 岁 老中医 临走前 说出 祛斑 秘方 每天 抹 一抹 它 三天 美白 十天 淡斑',
#  '104 国道 青 沧县 交界处 拦路 收费 是 青县 人士',
#  '107 国道 养 狗场 有 几千只 狗 等待 被 领养',
#  '107 国道 养 狗场 有 几千只 狗 等待 被 领养',
#  '108 岁 老人 长寿 秘诀 常 吃 它 高血压 心脏病 绕道 走 便宜 又 有效',
#  '107 国道 养 狗场 有 几千只 狗 等待 被 领养',
#  '10 万 人口 特大 镇 将 升级 为 市 江苏省 如皋市 哪些 镇有 机会 升级',
#  '10 w 北京 天津 发布 最严 停工 令 应对 大气污染 丨 中国 绿色 公号 周榜 第 115 期',
#  '10 万 人口 特大 镇 将 升级 为 市 浙江 哪些 镇有 机会 升级 有 你 家乡 没',
#  '10 万 人口 特大 镇 将 升级 为 市 浙江 哪些 镇有 机会 升级 有 你 家乡 没',
#  '10 万 人口 特大 镇 将 升级 为 市 江苏省 如皋市 哪些 镇有 机会 升级',
#  '10 万左右 最 省油 的 车 日 系 占 三席 冠军 得主 你 绝 想不到',
#  '10 万左右 最 省油 的 车 日 系 占 三席 冠军 得主 你 绝 想不到',
#  '10 万左右 最 省油 的 车 日 系 占 三席 冠军 得主 你 绝 想不到',
#  '10 万左右 最 省油 的 车 日 系 占 三席 冠军 得主 你 绝 想不到',
#  '10 个 喝水 习惯 最 损 健康 吃 咸 了 不 马上 喝水',
#  '10 万左右 最 省油 的 车 日 系 占 三席 冠军 得主 你 绝 想不到',
#  '10 个 信号 暗示 心血管 疾病 找 上 你 每天 吃 1 物 可 把 血压 降到 140 以下',
#  '10 万左右 最 省油 的 车 日 系 占 三席 冠军 得主 你 绝 想不到',
#  '10 个 喝水 习惯 最 损 健康 吃 咸 了 不 马上 喝水',
#  '10 个 喝水 习惯 最 损 健康 吃 咸 了 不 马上 喝水',
#  '10 个 喝水 习惯 最 损 健康 吃 咸 了 不 马上 喝水',
#  '10 万左右 最 省油 的 车 日 系 占 三席 冠军 得主 你 绝 想不到',
#  '10 个 喝水 习惯 最 损 健康 吃 咸 了 不 马上 喝水',
#  '10 个 喝水 习惯 最 损 健康 吃 咸 了 不 马上 喝水',
#  '10 个 孩子 空腹吃 荔枝 死亡 医生 的 呼吁 为 所有人 敲响警钟',
#  '10 个 孩子 空腹吃 荔枝 死亡 医生 的 呼吁 为 所有人 敲响警钟',
#  '10 个 孩子 空腹吃 荔枝 死亡 医生 的 呼吁 为 所有人 敲响警钟',
#  '10 个 喝水 习惯 最 损 健康 吃 咸 了 不 马上 喝水',
#  '10 个 孩子 空腹吃 荔枝 死亡 医生 的 呼吁 为 所有人 敲响警钟',
#  '10 个 孩子 空腹吃 荔枝 死亡 医生 的 呼吁 为 所有人 敲响警钟',
#  '10 个 孩子 空腹吃 荔枝 死亡 医生 的 呼吁 为 所有人 敲响警钟',
#  '10 个 孩子 空腹吃 荔枝 死亡 医生 的 呼吁 为 所有人 敲响警钟',
#  '10 个 孩子 空腹吃 荔枝 死亡 医生 的 呼吁 为 所有人 敲响警钟',
#  '10 个 孩子 空腹吃 荔枝 死亡 医生 的 呼吁 为 所有人 敲响警钟',
#  '10 个 孩子 空腹吃 荔枝 死亡 医生 的 呼吁 为 所有人 敲响警钟',
#  '10 个 孩子 空腹吃 荔枝 死亡 医生 的 呼吁 为 所有人 敲响警钟',
#  '10 个 快速 减肥 小 偏方 想 不想 试试',
#  '10 个 快速 美白 的 小 技巧 赶紧 get 起来',
#  '10 个 快速 减肥 小 偏方 想 不想 试试',
#  '10 个 祛斑 小妙 招 快速 帮 你 恢复 美白 肌肤',
#  '10 个 富豪 里 9 个 手相 都 有 这 条线 顶级 相术 家 告诉 你 什么 人能 发财',
#  '10 个 被 抓拍 到 的 诡异 天象 奇观 难道真 有 外星人',
#  '10 人 以上 微信 群会 受到 网警 自动 监控 还有 被 查封 可能性',
#  '10 人 以上 微信 群会 受到 网警 自动 监控 还有 被 查封 可能性',
#  '10 个 祛斑 小妙 招 快速 帮 你 恢复 美白 肌肤',
#  '10 个 被 抓拍 到 的 诡异 天象 奇观 难道真 有 外星人',
#  '10 人 以上 微信 群会 受到 网警 自动 监控 还有 被 查封 可能性',
#  '10 人 以上 微信 群会 受到 网警 自动 监控 还有 被 查封 可能性',
#  '10 人 以上 微信 群会 受到 网警 自动 监控 还有 被 查封 可能性',
#  '10 人 以上 微信 群会 受到 网警 自动 监控 还有 被 查封 可能性',
#  '10 人 以上 微信 群会 受到 网警 自动 监控 还有 被 查封 可能性',
#  '10 人 以上 微信 群会 受到 网警 自动 监控 还有 被 查封 可能性',
#  '10 人 以上 微信 群会 受到 网警 自动 监控 还有 被 查封 可能性',
#  '10 个 被 抓拍 到 的 诡异 天象 奇观 难道真 有 外星人',
#  '10 亿年 前 火星 可能 存在 高级 文明 玛雅人',
#  '10 亿年 前 火星 可能 存在 高级 文明 玛雅人',
#  '10 人 以上 微信 群会 受到 网警 自动 监控 还有 被 查封 可能性',
#  '10 亿年 前 火星 可能 存在 高级 文明 玛雅人',
#  '10 亿年 前 火星 可能 存在 高级 文明 玛雅人',
#  '10 亿年 前 火星 可能 存在 高级 文明 玛雅人',
#  '10 亿年 前 火星 可能 存在 高级 文明 玛雅人',
#  '10 亿年 前 火星 可能 存在 高级 文明 玛雅人',
#  '10 人 以上 微信 群会 受到 网警 自动 监控 还有 被 查封 可能性',
#  '10 亿年 前 火星 可能 存在 高级 文明 玛雅人',
#  '10 亿年 前 火星 可能 存在 高级 文明 玛雅人',
#  '10 余所 名校 将 进驻 副 中心 辐射 北三县',
#  '10 余所 名校 将 进驻 副 中心 辐射 北三县',
#  '10 余所 名校 将 进驻 副 中心 辐射 北三县',
#  '10 余所 名校 将 进驻 副 中心 辐射 北三县',
#  '10 余所 名校 将 进驻 副 中心 辐射 北三县',
#  '10 余所 名校 将 进驻 副 中心 辐射 北三县',
#  '10 余所 名校 将 进驻 副 中心 辐射 北三县',
#  '10 余所 名校 将 进驻 副 中心 辐射 北三县',
#  '10 余所 名校 将 进驻 副 中心 辐射 北三县',
#  '10 余所 名校 将 进驻 副 中心 辐射 北三县',
#  '10 余所 名校 将 进驻 副 中心 辐射 北三县',
#  '10 余所 名校 将 进驻 副 中心 辐射 北三县',
#  '10 余所 名校 将 进驻 副 中心 辐射 北三县',
#  '10 余所 名校 将 进驻 副 中心 辐射 北三县',
#  '10 余所 名校 将 进驻 副 中心 辐射 北三县',
#  '10 余所 名校 将 进驻 副 中心 辐射 北三县',
#  '10 余所 名校 将 进驻 副 中心 辐射 北三县',
#  '10 余所 名校 将 进驻 副 中心 辐射 北三县',
#  '10 元 大团结 要是 这样 的 价值 破 万 就 不是 问题 快 看看 你 有没有',
#  '10 余所 名校 将 进驻 副 中心 辐射 北三县',
#  '10 余所 名校 将 进驻 副 中心 辐射 北三县',
#  '10 克 山楂 10 克 荷叶 睡 前 喝一杯 燃脂 一整夜 体重 永保 2 位数',
#  '10 克 山楂 10 克 荷叶 睡 前 喝一杯 燃脂 一整夜 体重 永保 2 位数',
#  '10 几年 的 高血压 用 了 一种 花 就 解决 了 血压 猛降 需要 的 速 收藏',
#  '10 分钟 快速 发面 不用 酵母粉 试试 这样 做 蒸出 的 馒头 倍 好吃',
#  '10 分钟 就 能 盗取 指纹 解锁 手机',
#  '10 分钟 快速 发面 不用 酵母粉 试试 这样 做 蒸出 的 馒头 倍 好吃',
#  '10 克 山楂 10 克 荷叶 睡 前 喝一杯 燃脂 一整夜 体重 永保 2 位数',
#  '10 号线 车厢 内 乘客 突然 狂奔',
#  '10 号线 车厢 内 乘客 突然 狂奔',
#  '10 名 女孩 泳池 游泳 竟 意外 怀孕 谁 是 爸爸 至今 无人 承认',
#  '10 号线 车厢 内 乘客 突然 狂奔',
#  '10 分钟 快速 发面 不用 酵母粉 试试 这样 做 蒸出 的 馒头 倍 好吃',
#  '10 名 女孩 泳池 游泳 竟 意外 怀孕 谁 是 爸爸 至今 无人 承认',
#  '10 名 女孩 泳池 游泳 竟 意外 怀孕 谁 是 爸爸 至今 无人 承认',
#  '10 名 女孩 泳池 游泳 竟 意外 怀孕 谁 是 爸爸 至今 无人 承认',
#  '10 分钟 快速 发面 不用 酵母粉 试试 这样 做 蒸出 的 馒头 倍 好吃',
#  '10 名 女孩 泳池 游泳 竟 意外 怀孕 谁 是 爸爸 至今 无人 承认',
#  '10 名 女孩 泳池 游泳 竟 意外 怀孕 谁 是 爸爸 至今 无人 承认',
#  '10 名 女孩 泳池 游泳 竟 意外 怀孕 谁 是 爸爸 至今 无人 承认',
#  '10 块 1 年 到 了 150 农村 新农 合 14 年 涨 15 倍 3 个 农民 不用 再 拿 一分',
#  '10 块 1 年 到 了 150 农村 新农 合 14 年 涨 15 倍 3 个 农民 不用 再 拿 一分',
#  '10 块 1 年 到 了 150 农村 新农 合 14 年 涨 15 倍 3 个 农民 不用 再 拿 一分',
#  '10 块 1 年 到 了 150 农村 新农 合 14 年 涨 15 倍 3 个 农民 不用 再 拿 一分',
#  '10 多年 的 颈椎病 和 肩周炎 老中医 的 这个 中药 秘方 治 好 超级 管用',
#  '10 天吃瘦 15 斤 的 食谱 是 什么样 的 已经 有 5000 人 成功 瘦身',
#  '10 天吃瘦 15 斤 的 食谱 是 什么样 的 已经 有 5000 人 成功 瘦身',
#  '10 天吃瘦 15 斤 的 食谱 是 什么样 的 已经 有 5000 人 成功 瘦身',
#  '10 天吃瘦 15 斤 的 食谱 是 什么样 的 已经 有 5000 人 成功 瘦身',
#  '10 天吃瘦 15 斤 的 食谱 是 什么样 的 已经 有 5000 人 成功 瘦身',
#  '10 天吃瘦 15 斤 的 食谱 是 什么样 的 已经 有 5000 人 成功 瘦身',
#  '10 天吃瘦 15 斤 的 食谱 是 什么样 的 已经 有 5000 人 成功 瘦身',
#  '10 天吃瘦 15 斤 的 食谱 是 什么样 的 已经 有 5000 人 成功 瘦身',
#  '10 天吃瘦 15 斤 的 食谱 是 什么样 的 已经 有 5000 人 成功 瘦身',
#  '10 天吃瘦 15 斤 的 食谱 是 什么样 的 已经 有 5000 人 成功 瘦身',
#  '10 天 瘦 20 斤 说谎 你 打 我 瘦身 减肥 天天 坚持 吃 它 身材 越来越 好',
#  '10 岁 女孩 做 阑尾 手术 被 切 子宫 医院 开始 反扑',
#  '10 岁 女孩 做 阑尾 手术 被 切 子宫 医院 开始 反扑',
#  '10 岁 儿子 腹痛 父母 竟 用 蜈蚣 蝎子 以毒攻毒 医生 抢救 无力回天',
#  '10 天 瘦 20 斤 说谎 你 打 我 瘦身 减肥 天天 坚持 吃 它 身材 越来越 好',
#  '10 岁 民工 娃 被 那英 睡 骂 赶下台 流泪 一首 歌唱 哭 全场 那英 被迫 离场',
#  '10 岁 女孩 做 阑尾 手术 被 切 子宫 医院 开始 反扑',
#  '10 岁 民工 娃 被 那英 睡 骂 赶下台 流泪 一首 歌唱 哭 全场 那英 被迫 离场',
#  '10 岁 民工 娃 被 那英 睡 骂 赶下台 流泪 一首 歌唱 哭 全场 那英 被迫 离场',
#  '10 岁 民工 娃 被 那英 睡 骂 赶下台 流泪 一首 歌唱 哭 全场 那英 被迫 离场',
#  '10 岁 民工 娃 被 那英 睡 骂 赶下台 流泪 一首 歌唱 哭 全场 那英 被迫 离场',
#  '10 岁 民工 娃 被 那英 睡 骂 赶下台 流泪 一首 歌唱 哭 全场 那英 被迫 离场',
#  '10 岁 民工 娃 被 那英 睡 骂 赶下台 流泪 一首 歌唱 哭 全场 那英 被迫 离场',
#  '10 岁 民工 娃 被 那英 睡 骂 赶下台 流泪 一首 歌唱 哭 全场 那英 被迫 离场',
#  '10 岁 民工 娃 被 那英 睡 骂 赶下台 流泪 一首 歌唱 哭 全场 那英 被迫 离场',
#  '10 岁 民工 娃 被 那英 睡 骂 赶下台 流泪 一首 歌唱 哭 全场 那英 被迫 离场',
#  '10 岁 男孩 吃辣 条 导致 肝 衰竭 可 自家 娃 也 爱 吃 怎么办',
#  '10 岁 男孩 吃辣 条 导致 肝 衰竭 可 自家 娃 也 爱 吃 怎么办',
#  '10 岁 男孩 腹痛 难忍 父母 中药 以毒攻毒 医生 全力 抢救 无力回天',
#  '10 岁 男孩 常 吃辣 条 导致 肝 衰竭 你 还 敢 多 吃 吗',
#  '10 岁 男孩 常 吃辣 条 导致 肝 衰竭 你 还 敢 多 吃 吗',
#  '10 岁 男孩 吃辣 条 导致 肝 衰竭 可 自家 娃 也 爱 吃 怎么办',
#  '10 岁 男孩 腹痛 难忍 父母 中药 以毒攻毒 医生 全力 抢救 无力回天',
#  '10 岁 男孩 腹痛 难忍 父母 中药 以毒攻毒 医生 全力 抢救 无力回天',
#  '10 年 之后 万元 等于 现在 多少 钱 说 出来 你 都 不敢相信',
#  '10 岁 男孩 腹痛 难忍 父母 中药 以毒攻毒 医生 全力 抢救 无力回天',
#  '10 年 之后 万元 等于 现在 多少 钱 说 出来 你 都 不敢相信',
#  '10 年前 已经 领证 43 岁 何炅 隐藏 多年 的 妻子 和 儿子 终 曝光',
#  '10 年后 1 万元 相当于 现在 多少 钱 太 可怕 了 说 出来 你 都 不敢 信',
#  '10 年后 1 万元 相当于 现在 多少 钱 太 可怕 了 说 出来 你 都 不敢 信',
#  '10 年后 1 万元 相当于 现在 多少 钱 太 可怕 了 说 出来 你 都 不敢 信',
#  '10 年前 花 1 万 买 了 一百枚 钱币 专家 鉴定 后 一枚 钱币 值 20 万',
#  '10 年后 1 万元 相当于 现在 多少 钱 太 可怕 了 说 出来 你 都 不敢 信',
#  '10 年后 1 万元 相当于 现在 多少 钱 太 可怕 了 说 出来 你 都 不敢 信',
#  '10 年后 1 万元 相当于 现在 多少 钱 太 可怕 了 说 出来 你 都 不敢 信',
#  '10 年后 1 万元 相当于 现在 多少 钱 太 可怕 了 说 出来 你 都 不敢 信',
#  '10 年后 1 万元 相当于 现在 多少 钱 太 可怕 了 说 出来 你 都 不敢 信',
#  '10 年后 1 万元 相当于 现在 多少 钱 太 可怕 了 说 出来 你 都 不敢 信',
#  '10 年后 1 万元 相当于 现在 多少 钱 说 出来 你 都 不敢 信',
#  '10 年后 1 万元 相当于 现在 多少 钱 说 出来 你 都 不敢 信',
#  '10 年后 1 万元 相当于 现在 多少 钱 说 出来 你 都 不敢 信',
#  '10 年后 1 万元 相当于 现在 多少 钱 说 出来 你 都 不敢 信',
#  '10 年后 1 万元 相当于 现在 多少 钱 说 出来 你 都 不敢 信',
#  '10 年后 1 万元 相当于 现在 多少 钱 说 出来 你 都 不敢 信',
#  '10 年后 1 万元 相当于 现在 多少 钱 说 出来 你 都 不敢 信',
#  '10 年后 1 万元 相当于 现在 多少 钱 说 出来 你 都 不敢 信',
#  '10 年后 1 万元 相当于 现在 多少 钱 说 出来 你 都 不敢 信',
#  '10 年后 1 万元 相当于 现在 多少 钱 说 出来 你 都 不敢 信',
#  '10 年后 1 万元 相当于 现在 多少 钱 说 出来 你 都 不敢 信',
#  '10 年后 1 万元 相当于 现在 多少 钱 说 出来 有人 会 惊呆',
#  '10 年后 1 万元 相当于 现在 多少 钱 说 出来 有人 会 惊呆',
#  '10 年后 1 万元 相当于 现在 多少 钱 说 出来 有人 会 惊呆',
#  '10 年后 1 万元 相当于 现在 多少 钱 说 出来 有人 会 惊呆',
#  '10 年后 1 万元 相当于 现在 多少 钱 说 出来 有人 会 惊呆',
#  '10 年后 1 万元 相当于 现在 多少 钱 说 出来 有人 会 惊呆',
#  '10 年后 1 万元 相当于 现在 多少 钱 说 出来 有人 会 惊呆',
#  '10 年后 1 万元 相当于 现在 多少 钱 说 出来 有人 会 惊呆',
#  '10 年后 1 万元 相当于 现在 多少 钱 说 出来 有人 会 惊呆',
#  '10 年后 陈冠希 说出 了 当年 留下 张柏芝 照片 原因',
#  '10 年后 陈冠希 说出 了 当年 留下 张柏芝 照片 原因',
#  '10 年后 陈冠希 说出 了 当年 留下 张柏芝 照片 原因',
#  '10 年后 陈冠希 说出 了 当年 留下 张柏芝 照片 原因',
#  '10 年后 陈冠希 说出 了 当年 留下 张柏芝 照片 原因',
#  '10 年后 陈冠希 说出 了 当年 留下 张柏芝 照片 原因',
#  '10 年后 陈冠希 说出 了 当年 留下 张柏芝 照片 原因',
#  '10 年后 陈冠希 说出 了 当年 留下 张柏芝 照片 原因',
#  '10 年后 陈冠希 说出 了 当年 留下 张柏芝 照片 原因',
#  '10 年后 陈冠希 说出 了 当年 留下 张柏芝 照片 原因',
#  '10 年后 陈冠希 说出 了 当年 留下 张柏芝 照片 原因',
#  '10 年后 的 100 万 会值 多少 钱 说 出来 估计 你 都 不敢相信',
#  '10 年后 的 100 万 会值 多少 钱 说 出来 估计 你 都 不敢相信',
#  '10 年后 的 100 万 会值 多少 钱 说 出来 估计 你 都 不敢相信',
#  '10 年后 的 100 万 会值 多少 钱 说 出来 估计 你 都 不敢相信',
#  '10 年后 的 100 万 会值 多少 钱 说 出来 估计 你 都 不敢相信',
#  '10 年后 的 100 万 会值 多少 钱 说 出来 估计 你 都 不敢相信',
#  '10 年后 的 100 万 会值 多少 钱 说 出来 估计 你 都 不敢相信',
#  '10 年后 的 100 万 会值 多少 钱 说 出来 估计 你 都 不敢相信',
#  '10 年后 的 100 万 会值 多少 钱 说 出来 估计 你 都 不敢相信',
#  '10 年后 的 100 万 会值 多少 钱 说 出来 估计 你 都 不敢相信',
#  '10 年后 的 一万元 相当于 现在 的 多少 钱 看 完 视频 后 心情 复杂',
#  '10 年后 的 100 万 会值 多少 钱 说 出来 估计 你 都 不敢相信',
#  '10 年后 的 100 万 会值 多少 钱 说 出来 估计 你 都 不敢相信',
#  '10 年后 的 1 万元 相当于 现在 的 多少 钱',
#  '10 年后 的 一万元 相当于 现在 的 多少 钱 看 完 视频 后 心情 复杂',
#  '10 年 售楼 小姐 悄悄 透露 买房 万万 不要 买 着 一层 灰尘 大 不 健康',
#  '10 年 售楼 小姐 悄悄 透露 买房 万万 不要 买 着 一层 灰尘 大 不 健康',
#  '10 年后 100 万 人民币 会 贬值 成 多少 钱 看完 后 还是 赶紧 投资 吧',
#  '10 年 售楼 小姐 悄悄 透露 买房 万万 不要 买 着 一层 灰尘 大 不 健康',
#  '10 年 售楼 小姐 透露 买房 万万 不要 买 这 几种 房子 懂行 人 都 不会 要',
#  '10 年 售楼 小姐 透露 买房 万万 不要 买 这 几种 房子 懂行 人 都 不会 要',
#  '10 年 售楼 小姐 悄悄 透露 买房 万万 不要 买 着 一层 灰尘 大 不 健康',
#  '10 年 售楼 小姐 透露 买房 万万 不要 买 这 几种 房子 懂行 人 都 不会 要',
#  '10 年 售楼 小姐 透露 买房 万万 不要 买 这 几种 房子 懂行 人 都 不会 要',
#  '10 年 售楼 小姐 透露 买房 万万 不要 买 这 几种 房子 懂行 人 都 不会 要',
#  '10 年 售楼 小姐 透露 买房 万万 不要 买 这 几种 房子 懂行 人 都 不会 要',
#  '10 年 售楼 小姐 透露 买房 装修 万万 不要 买 顶楼 聪明人 都 不会 买',
#  '10 年 售楼 小姐 透露 买房 装修 万万 不要 买 顶楼 聪明人 都 不会 买',
#  '10 年 售楼 小姐 透露 买房 装修 万万 不要 买 顶楼 聪明人 都 不会 买',
#  '10 年 售楼 小姐 透露 买房 装修 万万 不要 买 顶楼 聪明人 都 不会 买',
#  '10 年 售楼 小姐 透露 买房 万万 不要 买 这 几种 房子 懂行 人 都 不会 要',
#  '10 年 售楼 小姐 透露 买房 装修 万万 不要 买 顶楼 聪明人 都 不会 买',
#  '10 年 售楼 小姐 透露 买房 装修 万万 不要 买 顶楼 聪明人 都 不会 买',
#  '10 年 白发 生姜 加 它 洗头 分钟 急速 变黑 在家 可 做 才 花 2 块钱',
#  '10 年 白发 生姜 加 它 洗头 分钟 急速 变黑 在家 可 做 才 花 2 块钱',
#  '10 年 白发 生姜 加 它 洗头 分钟 急速 变黑 在家 可 做 才 花 2 块钱',
#  '10 年 白发 生姜 加 它 洗头 分钟 急速 变黑 在家 可 做 才 花 2 块钱',
#  '10 年 的 老 鼻炎 只 需 一把 花生 煮水 三天 改善 十天 断根 无 复发',
#  '10 年 的 脚气 完全 放弃 谁料 遇到 偏方 7 天 之内 彻底 断根',
#  '10 年 的 脚气 完全 放弃 谁料 遇到 偏方 7 天 之内 彻底 断根',
#  '10 年 的 脚气 完全 放弃 谁料 遇到 偏方 7 天 之内 彻底 断根',
#  '10 年 的 脚气 完全 放弃 谁料 遇到 偏方 7 天 之内 彻底 断根',
#  '10 年 的 腰 突 都 不用 怕 用 了 这 老 偏方 治疗 腰间盘 突出 从此 不 复发',
#  '10 年 糖尿病 喝一杯 它 就 解决 快速 降血糖 血糖 稳定 血压 也 低 了',
#  '10 年 糖尿病 喝一杯 它 就 解决 快速 降血糖 血糖 稳定 血压 也 低 了',
#  '10 年 老股民 揭秘 买入 暴涨 形态 股票 书上 都 找 不到',
#  '10 年老 铁 生锈 一点 都 不慌 一个 土豆 教 你 搞定 一切 轻松 祛除 铁锈',
#  '10 年老 铁 生锈 一点 都 不慌 一个 土豆 教 你 搞定 一切 轻松 祛除 铁锈',
#  '10 年 腰间盘 突出 被 一把 艾叶 给 根治 了 颈椎病 腰腿痛 也 管用',
#  '10 年 腰间盘 突出 被 一把 艾叶 给 根治 了 颈椎病 腰腿痛 也 管用',
#  '10 年 腰间盘 突出 被 一把 艾叶 给 根治 了 颈椎病 腰腿痛 也 管用',
#  '10 年 腰间盘 突出 被 一把 艾叶 给 根治 了 颈椎病 腰腿痛 也 管用',
#  '10 年 颈椎 富贵 包难 消 一杯 白酒 配 艾草 消除 颈椎 疾病 快 收藏',
#  '10 年 颈椎 富贵 包难 消 一杯 白酒 配 艾草 消除 颈椎 疾病 快 收藏',
#  '10 年 颈椎病 痛苦 经历 竟然 被 一把 玉米 给 治好 了 7 天 去 根 不 复发',
#  '10 年 颈椎病 痛苦 经历 竟然 被 一把 玉米 给 治好 了 7 天 去 根 不 复发',
#  '10 年 颈椎病 痛苦 经历 竟然 被 一把 玉米 给 治好 了 7 天 去 根 不 复发',
#  '10 年 颈椎病 痛苦 经历 竟然 被 一把 玉米 给 治好 了 7 天 去 根 不 复发',
#  '10 年 颈椎病 竟 被 南瓜子 治好 了 颈椎病 3 天 见效 7 天 去 根 不 复发',
#  '10 年 白发 生姜 加 它 洗头 分钟 急速 变黑 在家 可 做 才 花 2 块钱',
#  '10 年 颈椎病 竟 被 南瓜子 治好 了 颈椎病 3 天 见效 7 天 去 根 不 复发',
#  '10 年 颈椎病 竟 被 南瓜子 治好 了 颈椎病 3 天 见效 7 天 去 根 不 复发',
#  '10 年 高血压 花 了 8 万 用 一种 花 就 解决 了 血压 猛降',
#  '10 年 颈椎病 竟 被 南瓜子 治好 了 颈椎病 3 天 见效 7 天 去 根 不 复发',
#  '10 年 颈椎病 竟 被 南瓜子 治好 了 颈椎病 3 天 见效 7 天 去 根 不 复发',
#  '10 年 颈椎病 竟 被 南瓜子 治好 了 颈椎病 3 天 见效 7 天 去 根 不 复发',
#  '10 年 颈椎病 竟 被 南瓜子 治好 了 颈椎病 3 天 见效 7 天 去 根 不 复发',
#  '10 年 颈椎病 竟 被 南瓜子 治好 了 颈椎病 3 天 见效 7 天 去 根 不 复发',
#  '10 年 高血压 花 了 数十万 每天 来 一杯 血压 猛降 血糖 也 稳定 了',
#  '10 年 高血压 花 了 8 万 用 一种 花 就 解决 了 血压 猛降',
#  '10 年 颈椎病 竟 被 南瓜子 治好 了 颈椎病 3 天 见效 7 天 去 根 不 复发',
#  '10 年 高血压 花 了 8 万 用 一种 花 就 解决 了 血压 猛降',
#  '10 年 高血压 花 了 数十万 每天 来 一杯 血压 猛降 血糖 也 稳定 了',
#  '10 年 高血压 花 了 数十万 每天 来 一杯 血压 猛降 血糖 也 稳定 了',
#  '10 年 高血压 花 了 数十万 每天 来 一杯 血压 猛降 血糖 也 稳定 了',
#  '10 年 高血压 1 个 鹅蛋 2 粒 花椒 就 了断 用 几个 好几个 为 家人 收藏',
#  '10 年 高血压 花 了 数十万 每天 来 一杯 血压 猛降 血糖 也 稳定 了',
#  '10 年 高血压 1 个 鹅蛋 2 粒 花椒 就 了断 用 几个 好几个 为 家人 收藏',
#  '10 年 高血压 1 个 鹅蛋 2 粒 花椒 就 了断 用 几个 好几个 为 家人 收藏',
#  '10 年 高血压 一 古方 治 一好 一个 1 月 后 血压 稳降 请存',
#  '10 年 高血压 一 古方 治 一好 一个 1 月 后 血压 稳降 请存',
#  '10 年 高血压 一 古方 治 一好 一个 1 月 后 血压 稳降 请存',
#  '10 年 高血压 一 古方 治 一好 一个 1 月 后 血压 稳降 请存',
#  '10 年 高血压 一 古方 治 一好 一个 1 月 后 血压 稳降 请存',
#  '10 年 高血压 一 古方 治 一好 一个 1 月 后 血压 稳降 请存',
#  '10 年 高血压 一 古方 治 一好 一个 1 月 后 血压 稳降 请存',
#  '10 年 高血压 一 古方 治 一好 一个 1 月 后 血压 稳降 请存',
#  '10 年 高血压 一 古方 治 一好 一个 1 月 后 血压 稳降 请存',
#  '10 年 高血压 张仲景 一 古方 治 一个 好 一个 半个 月 血压 狂降 速存',
#  '10 年 高血压 张仲景 一 古方 治 一个 好 一个 半个 月 血压 狂降 速存',
#  '10 年 高血压 张仲景 一 古方 治 一个 好 一个 半个 月 血压 狂降 速存',
#  '10 年 高血压 张仲景 一 古方 治 一个 好 一个 半个 月 血压 狂降 速存',
#  '10 年 高血压 张仲景 一 古方 治 一个 好 一个 半个 月 血压 狂降 速存',
#  '10 年 高血压 张仲景 一 古方 治 一个 好 一个 半个 月 血压 狂降 速存',
#  '10 年 高血压 张仲景 一 古方 治 一个 好 一个 半个 月 血压 狂降 速存',
#  '10 年 鱼鳞病 鸡 皮肤 未 反复 1 个 偏方 轻松 解决 鱼鳞病 7 天 见效',
#  '10 年 高血压 张仲景 一 古方 治 一好 一个 1 月 后 血压 稳降 请存',
#  '10 年 高血压 张仲景 一 古方 治 一好 一个 1 月 后 血压 稳降 请存',
#  '10 年 鱼鳞病 鸡 皮肤 未 反复 1 个 偏方 轻松 解决 鱼鳞病 7 天 见效',
#  '10 年 鱼鳞病 鸡 皮肤 未 反复 1 个 偏方 轻松 解决 鱼鳞病 7 天 见效',
#  '10 年 鱼鳞病 鸡 皮肤 未 反复 1 个 偏方 轻松 解决 鱼鳞病 7 天 见效',
#  '10 年 鱼鳞病 鸡 皮肤 未 反复 1 个 偏方 轻松 解决 鱼鳞病 7 天 见效',
#  '10 年 鱼鳞病 鸡 皮肤 未 反复 1 个 偏方 轻松 解决 鱼鳞病 7 天 见效',
#  '10 年 鱼鳞病 鸡 皮肤 未 反复 1 个 偏方 轻松 解决 鱼鳞病 7 天 见效',
#  '10 年 鱼鳞病 鸡 皮肤 未 反复 1 个 偏方 轻松 解决 鱼鳞病 7 天 见效',
#  '10 日 娱乐 热点 徐子淇 要 5 胎 公公 说 奖赏 10 亿 而 郭晶晶 欲 生 3 胎 公公 却 反对',
#  '10 日 娱乐 热点 徐子淇 要 5 胎 公公 说 奖赏 10 亿 而 郭晶晶 欲 生 3 胎 公公 却 反对',
#  '10 日 文化 热点 越南 已 废除 汉字 百年 现 准备 恢复 称 是 民族特色',
#  '10 日 文化 热点 越南 已 废除 汉字 百年 现 准备 恢复 称 是 民族特色',
#  '10 日 文化 热点 越南 已 废除 汉字 百年 现 准备 恢复 称 是 民族特色',
#  '10 日 文化 热点 越南 已 废除 汉字 百年 现 准备 恢复 称 是 民族特色',
#  '10 日 文化 热点 越南 已 废除 汉字 百年 现 准备 恢复 称 是 民族特色',
#  '10 日 文化 热点 越南 已 废除 汉字 百年 现 准备 恢复 称 是 民族特色',
#  '10 日 娱乐 热点 徐子淇 要 5 胎 公公 说 奖赏 10 亿 而 郭晶晶 欲 生 3 胎 公公 却 反对',
#  '10 日 文化 热点 越南 已 废除 汉字 百年 现 准备 恢复 称 是 民族特色',
#  '10 日 热点新闻 前 工程师 爆料 Intel 将 取消 至尊版 CPU 品牌',
#  '10 日 文化 热点 越南 已 废除 汉字 百年 现 准备 恢复 称 是 民族特色',
#  '10 日 文化 热点 越南 已 废除 汉字 百年 现 准备 恢复 称 是 民族特色',
#  '10 日 热点新闻 前 工程师 爆料 Intel 将 取消 至尊版 CPU 品牌',
#  '10 日 文化 热点 越南 已 废除 汉字 百年 现 准备 恢复 称 是 民族特色',
#  '10 日 热点新闻 前 工程师 爆料 Intel 将 取消 至尊版 CPU 品牌',
#  '10 月 12 日 起 全国 地区 大卡车 将 统一 限重 31 吨 超载 最高 可 罚款 3 万',
#  '10 月 15 号 起 驾驶证 替人 销分 新规 已 全面实施 被 查住 扣 12 分罚 5000',
#  '10 日 热点新闻 前 工程师 爆料 Intel 将 取消 至尊版 CPU 品牌',
#  '10 月 15 号 起 驾驶证 替人 销分 新规 已 全面实施 被 查住 扣 12 分罚 5000',
#  '10 月 15 号 起 驾驶证 替人 销分 新规 已 全面实施 被 查住 扣 12 分罚 5000',
#  '10 月 15 号 起 驾驶证 替人 销分 新规 已 全面实施 被 查住 扣 12 分罚 5000',
#  '10 月 15 号 起 驾驶证 替人 销分 新规 已 全面实施 被 查住 扣 12 分罚 5000',
#  '10 月 15 号 起 驾驶证 替人 销分 新规 已 全面实施 被 查住 扣 12 分罚 5000',
#  '10 月 15 号 起 驾驶证 替人 销分 新规 已 全面实施 被 查住 扣 12 分罚 5000',
#  '10 月 15 号 起 驾驶证 替人 销分 新规 已 全面实施 被 查住 扣 12 分罚 5000',
#  '10 月 15 号 起 驾驶证 替人 销分 新规 已 全面实施 被 查住 扣 12 分罚 5000',
#  '10 月 15 号 起 驾驶证 替人 销分 新规 已 全面实施 被 查住 扣 12 分罚 5000',
#  '10 月 15 号 起 驾驶证 替人 销分 新规 已 全面实施 被 查住 扣 12 分罚 5000',
#  '10 月 15 号 起 驾驶证 替人 销分 新规 已 全面实施 被 查住 扣 12 分罚 5000',
#  '10 月 17 号 起 驾驶证 替人 销分 惩罚 已 全面实施 被 查住 扣 12 分罚 5000',
#  '10 月 15 日 执行 新 的 交通法规',
#  '10 月 17 号 起 驾驶证 替人 销分 惩罚 已 全面实施 被 查住 扣 12 分罚 5000',
#  '10 月 16 日 起 新交 规 执行',
#  '10 月 17 号 起 驾驶证 替人 销分 新规 已 全面实施 被 查住 扣 12 分罚 5000',
#  '10 月 15 号 起 驾驶证 替人 销分 新规 已 全面实施 被 查住 扣 12 分罚 5000',
#  '10 月 17 号 起 驾驶证 替人 销分 新规 已 全面实施 被 查住 扣 12 分罚 5000',
#  '10 月 17 号 起 驾驶证 替人 销分 新规 已 全面实施 被 查住 扣 12 分罚 5000',
#  '10 月 17 日 起 驾驶证 替人 销分 新规 实施 一经 发现 扣 12 分罚 5000',
#  '10 月 17 日 起 驾驶证 替人 销分 新规 实施 一经 发现 扣 12 分罚 5000',
#  '10 月 17 号 起 驾驶证 替人 销分 新规 已 全面实施 被 查住 扣 12 分罚 5000',
#  '10 月 17 日 起 驾驶证 替人 销分 新规 实施 一经 发现 扣 12 分罚 5000',
#  '10 月 17 日 起 驾驶证 替人 销分 新规 实施 一经 发现 扣 12 分罚 5000',
#  '10 月 17 日 起 驾驶证 替人 销分 新规 实施 一经 发现 扣 12 分罚 5000',
#  '10 月 17 日 起 驾驶证 替人 销分 新规 实施 一经 发现 扣 12 分罚 5000',
#  '10 月 17 日 起 驾驶证 替人 销分 新规 实施 一经 发现 扣 12 分罚 5000',
#  '10 月 17 日 起 驾驶证 替人 销分 新规 实施 一经 发现 扣 12 分罚 5000',
#  '10 月 17 日 起 驾驶证 替人 销分 新规 实施 一经 发现 扣 12 分罚 5000',
#  '10 月 17 日 起 驾驶证 替人 销分 新规 实施 一经 发现 扣 12 分罚 5000',
#  '10 月 17 日 起 驾驶证 替人 销分 新规 实施 一经 发现 扣 12 分罚 5000',
#  '10 月 18 日本 东京 惊现 神秘 UFO 外星人 来 地球 予以 何为',
#  '10 月 18 日本 东京 惊现 神秘 UFO 外星人 来 地球 予以 何为',
#  '10 月 18 日本 东京 惊现 神秘 UFO 外星人 来 地球 予以 何为',
#  '10 月 18 日本 东京 惊现 神秘 UFO 外星人 来 地球 予以 何为',
#  '10 月 18 日本 东京 惊现 神秘 UFO 外星人 来 地球 予以 何为',
#  '10 月 18 日本 东京 惊现 神秘 UFO 外星人 来 地球 予以 何为',
#  '10 月 1 号 起 这 种 东西 切记 不要 放车 内 被 交警 发现 将 罚款',
#  '10 月 1 日 新 规 出台 后 驾驶证 代扣 分 已经 行不通 了',
#  '10 月 1 号 起 这 种 东西 切记 不要 放车 内 被 交警 发现 将 罚款',
#  '10 月 1 日 新 规 出台 后 驾驶证 代扣 分 已经 行不通 了',
#  '10 月 1 号 起 这 种 东西 切记 不要 放车 内 被 交警 发现 将 罚款',
#  '10 月 1 日 新 规 出台 后 驾驶证 代扣 分 已经 行不通 了',
#  '10 月 1 日 新 规 出台 后 驾驶证 代扣 分 已经 行不通 了',
#  '10 月 1 日 新 规 出台 后 驾驶证 代扣 分 已经 行不通 了',
#  '10 月 1 日 新 规 出台 后 驾驶证 代扣 分 已经 行不通 了',
#  '10 月 1 日 新 规 出台 后 驾驶证 代扣 分 已经 行不通 了',
#  '10 月 1 日 新 规 出台 后 驾驶证 代扣 分 已经 行不通 了',
#  '10 月 1 日 新 规 出台 后 驾驶证 代扣 分 已经 行不通 了',
#  '10 月 1 日 新 规 出台 后 驾驶证 代扣 分 已经 行不通 了',
#  '10 月 1 日 起 城管 摊贩 一家人 接下来 只 需 农户 持证 上岗 了解 下 吧',
#  '10 月 1 日 新 规 出台 后 驾驶证 代扣 分 已经 行不通 了',
#  '10 月 1 日 起 城管 摊贩 一家人 接下来 只 需 农户 持证 上岗 了解 下 吧',
#  '10 月 1 日 起 农民 进城 摆摊 合法化 不再 属于 无证 经营 了',
#  '10 月 1 日 起 农民 进城 摆摊 合法化 不再 属于 无证 经营 了',
#  '10 月 1 日 起 老年 代步车 合法化 满足 这 几个 要求 才能 上路 行驶',
#  '10 月 1 日 起 农民 进城 摆摊 合法化 不再 属于 无证 经营 了',
#  '10 月 1 日 起 农民 进城 摆摊 合法化 不再 属于 无证 经营 了',
#  '10 月 1 日 起 农民 进城 摆摊 售 农产品 合法化 农民 可以 放心 经营 了',
#  '10 月 1 日 起 农民 进城 摆摊 售 农产品 合法化 农民 可以 放心 经营 了',
#  '10 月 1 日 起 农民 进城 摆摊 售 农产品 合法化 农民 可以 放心 经营 了',
#  '10 月 1 日 起 农民 进城 摆摊 售 农产品 合法化 农民 可以 放心 经营 了',
#  '10 月 1 日 起 农民 进城 摆摊 售 农产品 合法化 农民 可以 放心 经营 了',
#  '10 月 1 日 起 农民 进城 摆摊 售 农产品 合法化 农民 可以 放心 经营 了',
#  '10 月 1 日 起 农民 进城 摆摊 售 农产品 合法化 农民 可以 放心 经营 了',
#  '10 月 1 日 起 农民 进城 摆摊 售 农产品 合法化 农民 可以 放心 经营 了',
#  '10 月 1 日 起 农民 进城 摆摊 售 农产品 合法化 农民 可以 放心 经营 了',
#  '10 月 1 日 起 农民 进城 摆摊 售 农产品 合法化 农民 可以 放心 经营 了',
#  '10 月 1 日 起 执行 驾照 新规 机动车 驾驶 人 考试 将 会 增加 科目 五',
#  '10 月 1 日 起 农民 进城 摆摊 售 农产品 合法化 农民 可以 放心 经营 了',
#  '10 月 1 日 起 执行 驾照 新规 机动车 驾驶 人 考试 将 会 增加 科目 五',
#  '10 月 1 日 起 农民 进城 摆摊 售 农产品 合法化 农民 可以 放心 经营 了',
#  '10 月 1 日 起 农民 进城 摆摊 售 农产品 合法化 农民 可以 放心 经营 了',
#  '10 月 1 日 起 没 考驾照 的 要 哭 了 驾校 只能 跟 您 说 对不起',
#  '10 月 1 日 起 执行 驾照 新规 机动车 驾驶 人 考试 将 会 增加 科目 五',
#  '10 月 25 日 起 卖 韭菜 要持 双证 了 否则 最高 罚款 万元',
#  '10 月 25 日 起 全国 地区 大卡车 将 统一 限重 31 吨 超载 最高 可 罚款 3 万',
#  '10 月 25 日 起 全国 地区 大卡车 将 统一 限重 31 吨 超载 最高 可 罚款 3 万',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 6 日 起 驾驶证 替人 消分 新 规将 正式 执行 以后 开车 要 注意',
#  '10 月 6 日 起 驾驶证 替人 消分 新 规将 正式 执行 以后 开车 要 注意',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 28 日 Baby 新剧 玩 消失 黄轩 居然 与 空气 飙戏 三天',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 月份 开始 驾驶证 替人 销分 新 规将 正式 实施 以后 开车 要 注意',
#  '10 月份 开始 驾驶证 替人 销分 新 规将 正式 实施 以后 开车 要 注意',
#  '10 月份 农村 冬季 取暖 补助 大致 分为 4 个 标准 以下 农民 可以 领取',
#  '10 月 财政支出 首 现年 内 负增长 去年 地方 基数 太 高',
#  '10 月 起 农村 退伍军人 高额 补贴 来 了 千万 别错过 了',
#  '10 月 股票 基金 平均 涨 2.12 商品 基金 下跌 2.26',
#  '10 月 起 小排量 汽车 车购税 减半 征收 已 购车 未 缴税 不能 享受',
#  '10 款 美味 饼干 功效 推荐 养胃 促 消化 无糖 均衡 营养 早餐 零食 均 可',
#  '10 月 起 农村 退伍军人 可 领取 高额 补贴 了 千万 别错过 了',
#  '10 款 美味 饼干 功效 推荐 养胃 促 消化 无糖 均衡 营养 早餐 零食 均 可',
#  '10 相克 食物 与 10 个 相宜 食物 值得 收藏',
#  '10 种 全世界 最毒 的 食物 有 一样 我们 经常 吃',
#  '10 点 19 分 内蒙古 锡盟 东乌旗 发生 地壳 推移 这 是 人类 第一次',
#  '10 种 变态 的 增高 方法 想 不长 都 难',
#  '10 种 变态 的 增高 方法 想 不长 都 难',
#  '10 种 变态 的 增高 方法 想 不长 都 难',
#  '10 点 19 分 内蒙古 锡盟 东乌旗 发生 地壳 推移 这 是 人类 第一次',
#  '10 种 变态 的 增高 方法 想 不长 都 难',
#  '10 种 室内 可以 帮助 我们 去 除甲醛 的 植物 快 来 看看 你家 有没有',
#  '10 月 8 日 平阴 往 黑风口 路段 连环撞 车 造成 16 死 27 伤 挖掘机 正在 清理 现场',
#  '10 种 室内 可以 帮助 我们 去 除甲醛 的 植物 快 来 看看 你家 有没有',
#  '10 种 室内 可以 帮助 我们 去 除甲醛 的 植物 快 来 看看 你家 有没有',
#  '10 种 室内 可以 帮助 我们 去 除甲醛 的 植物 快 来 看看 你家 有没有',
#  '10 种 室内 可以 帮助 我们 去 除甲醛 的 植物 快 来 看看 你家 有没有',
#  '10 种 最 容易 忽视 的 致癌 食物 我们 每天 都 在 吃',
#  '10 种 美颜 瘦身 果汁 喝 果汁 也 能 减肥',
#  '10 种 致癌 食物 名单 瓜子 居然 也 在 其中',
#  '10 种 让 女人 越 吃 越 漂亮 的 美容 养颜 的 食物 让 自己 棒棒 哒',
#  '10 种 有害 健康 的 食物 你 不该 吃',
#  '10 种 致癌 食物 名单 瓜子 居然 也 在 其中',
#  '10 种 致癌 食物 名单 瓜子 居然 也 在 其中',
#  '10 种 食物 是 糖尿病 的 克星',
#  '10 秒 学会 无需 任何 软件 免费 靠 谱 地 清理 微信 僵尸 粉',
#  '10 秒 学会 无需 任何 软件 免费 靠 谱 地 清理 微信 僵尸 粉',
#  '10 秒 学会 无需 任何 软件 免费 靠 谱 地 清理 微信 僵尸 粉',
#  '10 秒 学会 无需 任何 软件 免费 靠 谱 地 清理 微信 僵尸 粉',
#  '10 秒 学会 无需 任何 软件 免费 靠 谱 地 清理 微信 僵尸 粉',
#  '10 秒 学会 无需 任何 软件 免费 靠 谱 地 清理 微信 僵尸 粉',
#  '10 秒 学会 无需 任何 软件 免费 靠 谱 地 清理 微信 僵尸 粉',
#  '10 秒 学会 无需 任何 软件 免费 靠 谱 地 清理 微信 僵尸 粉',
#  '10 秒 学会 无需 任何 软件 免费 靠 谱 地 清理 微信 僵尸 粉',
#  '10 秒 学会 无需 任何 软件 免费 靠 谱 地 清理 微信 僵尸 粉',
#  '10 秒 学会 无需 任何 软件 免费 靠 谱 地 清理 微信 僵尸 粉',
#  '10 秒 学会 无需 任何 软件 免费 靠 谱 地 清理 微信 僵尸 粉',
#  '10 秒 学会 无需 任何 软件 免费 靠 谱 地 清理 微信 僵尸 粉',
#  '10 秒 学会 无需 任何 软件 免费 靠 谱 地 清理 微信 僵尸 粉',
#  '10 类人 最该 提防 胃癌 3 种 水果 可能 伤胃',
#  '10 秒 学会 无需 任何 软件 免费 靠 谱 地 清理 微信 僵尸 粉',
#  '10 秒 学会 无需 任何 软件 免费 靠 谱 地 清理 微信 僵尸 粉',
#  '10 秒 学会 无需 任何 软件 免费 靠 谱 地 清理 微信 僵尸 粉',
#  '10 部 真实 拍到 鬼 的 恐怖 灵异 视频 合集',
#  '10 马云 的 支付宝 新 推出 一个 功能 60 岁 以下 的 消费者 有福 了',
#  '10 部 真实 拍到 鬼 的 恐怖 灵异 视频 合集',
#  '10 马云 的 支付宝 新 推出 一个 功能 60 岁 以下 的 消费者 有福 了',
#  '10 马云 的 支付宝 新 推出 一个 功能 60 岁 以下 的 消费者 有福 了',
#  '10 马云 的 支付宝 新 推出 一个 功能 60 岁 以下 的 消费者 有福 了',
#  '110 求真 蘑菇 具有 富集 重金属 不能 食',
#  '10 马云 的 支付宝 新 推出 一个 功能 60 岁 以下 的 消费者 有福 了',
#  '10 马云 的 支付宝 新 推出 一个 功能 60 岁 以下 的 消费者 有福 了',
#  '10 马云 的 支付宝 新 推出 一个 功能 60 岁 以下 的 消费者 有福 了',
#  '11 亿 豪宅 网上 曝光 马云 回应 差点 我 就 信 啦',
#  '11 亿 豪宅 网上 曝光 马云 回应 差点 我 就 信 啦',
#  '11 亿 豪宅 网上 曝光 马云 回应 差点 我 就 信 啦',
#  '110 求真 蘑菇 具有 富集 重金属 不能 食',
#  '11 亿 豪宅 网上 曝光 马云 回应 差点 我 就 信 啦',
#  '11 亿 豪宅 网上 曝光 马云 回应 差点 我 就 信 啦',
#  '11 亿 豪宅 网上 曝光 马云 回应 差点 我 就 信 啦',
#  '11 岁 男孩 因为 生 吃 这个 患 肺吸虫 病 长 出 两个 包块 在 体内 游走',
#  '11 日 娱乐 精选 冯小刚 终于 开喷 战狼 2 了 你们 怎么 看',
#  '11 月 10 号 今日 淘宝 双十 一天 猫 密令 红包 双 11 支付宝 红包 口令',
#  '11 日 美食 热点 回顾 这些 水果 吃 过 3 种 的 是 土豪 吃 过 5 种 的 是 贵族 你 吃 过 几种 呢',
#  '11 月 10 号 今日 淘宝 双十 一天 猫 密令 红包 双 11 支付宝 红包 口令',
#  '11 月 10 号 今日 淘宝 双十 一天 猫 密令 红包 双 11 支付宝 红包 口令',
#  '11 月 10 号 今日 淘宝 双十 一天 猫 密令 红包 双 11 支付宝 红包 口令',
#  '11 月 10 号 今日 淘宝 双十 一天 猫 密令 红包 双 11 支付宝 红包 口令',
#  '11 月 16 日 疑似 神秘 巨型 UFO 出现 在 太阳 附近',
#  '11 月 10 号 今日 淘宝 双十 一天 猫 密令 红包 双 11 支付宝 红包 口令',
#  '11 月 10 号 今日 淘宝 双十 一天 猫 密令 红包 双 11 支付宝 红包 口令',
#  '11 月 16 日 疑似 神秘 巨型 UFO 出现 在 太阳 附近',
#  '11 月 16 日 提前 十天 生下 6 斤 的 健康 男 宝宝 说 说 我 生 男宝 的 症状',
#  '11 月 16 日 疑似 神秘 巨型 UFO 出现 在 太阳 附近',
#  '11 月 16 日 疑似 神秘 巨型 UFO 出现 在 太阳 附近',
#  '11 月 18 号 起 这 4 种 东西 切记 不要 放车 内 被 交警 发现 将 罚款 2000 元',
#  '11 月 16 日 疑似 神秘 巨型 UFO 出现 在 太阳 附近',
#  '11 月 18 号 起 这 4 种 东西 切记 不要 放车 内 被 交警 发现 将 罚款 2000 元',
#  '11 月 19 号 起 汽车 全新 年 审 新规 实行 首次 取消 5 个 收费 项目',
#  '11 月 18 号 起 这 4 种 东西 切记 不要 放车 内 被 交警 发现 将 罚款 2000 元',
#  '11 月 18 号 起 这 4 种 东西 切记 不要 放车 内 被 交警 发现 将 罚款 2000 元',
#  '11 月 19 号 起 汽车 全新 年 审 新规 实行 首次 取消 5 个 收费 项目',
#  '11 月 1 日 起 农民工 工资 上调 养老金 上涨 农村 五保 供养 补贴 增加',
#  '11 月 19 号 起 汽车 全新 年 审 新规 实行 首次 取消 5 个 收费 项目',
#  '11 月 1 日 起 农民工 工资 上调 养老金 上涨 农村 五保 供养 补贴 增加',
#  '11 月 1 日 起 农民工 工资 上调 养老金 上涨 农村 五保 供养 补贴 增加',
#  '11 月 1 日 起 农民工 工资 上调 养老金 上涨 农村 五保 供养 补贴 增加',
#  '11 月 1 日 起 农民工 工资 上调 养老金 上涨 农村 五保 供养 补贴 增加',
#  '11 月 1 日 起 农民工 工资 上调 养老金 上涨 农村 五保 供养 补贴 增加',
#  '11 月 1 日 起 农民工 工资 上调 养老金 上涨 农村 五保 供养 补贴 增加',
#  '11 月 27 日 沧州 红黄蓝 幼儿园 爆出 虐 童 事件 老师 被 带走 虐 童 事件 频发 该 如何 防范',
#  '11 月 27 日 沧州 红黄蓝 幼儿园 爆出 虐 童 事件 老师 被 带走 虐 童 事件 频发 该 如何 防范',
#  '11 月 27 日 沧州 红黄蓝 幼儿园 爆出 虐 童 事件 老师 被 带走 虐 童 事件 频发 该 如何 防范',
#  '11 月 1 日 起 卖 韭菜 没 两证 要 罚 5 万元 蔬菜 监管 从 它 开始',
#  '11 月 27 日 沧州 红黄蓝 幼儿园 爆出 虐 童 事件 老师 被 带走 虐 童 事件 频发 该 如何 防范',
#  '11 月 27 日 沧州 红黄蓝 幼儿园 爆出 虐 童 事件 老师 被 带走 虐 童 事件 频发 该 如何 防范',
#  '11 月 27 日 沧州 红黄蓝 幼儿园 爆出 虐 童 事件 老师 被 带走 虐 童 事件 频发 该 如何 防范',
#  '11 月 4 日 起 汽车 年 审新 规 正式 施行 取消 6 项 收费 车主 互相 告知',
#  '11 月 4 日 起 汽车 年 审新 规 正式 施行 取消 6 项 收费 车主 互相 告知',
#  '11 月 中国 手机 市场 出货量 暴跌 20 智能手机 为何 卖 不动 了',
#  '11 月 SUV 排行榜 出炉 哈弗 H6 月销量 突破 万辆 宝骏 510 怎么 了',
#  '11 月 4 日 起 汽车 年 审新 规 正式 施行 取消 6 项 收费 车主 互相 告知',
#  '11 月 27 日 沧州 红黄蓝 幼儿园 爆出 虐 童 事件 老师 被 带走 虐 童 事件 频发 该 如何 防范',
#  '11 月 SUV 排行榜 出炉 哈弗 H6 月销量 突破 万辆 宝骏 510 怎么 了',
#  '11 月 中国 手机 市场 出货量 暴跌 20 智能手机 为何 卖 不动 了',
#  '11 月份 之前 除了 这些 特殊 人 农民 每人 还 得 缴纳 一笔 费用',
#  '11 月份 之前 除了 这些 特殊 人 农民 每人 还 得 缴纳 一笔 费用',
#  '11 月份 之前 除了 这些 特殊 人 农民 每人 还 得 缴纳 一笔 费用',
#  '11 月份 公务员 的 工资 又 上涨 了 企业 退休 人员 养老金 有望 提高',
#  '11 月份 之前 除了 这些 特殊 人 农民 每人 还 得 缴纳 一笔 费用',
#  '11 月份 起 这 6 项 资金 开始 下发 请 农民 朋友 互相 转告',
#  '11 月 农民工 工资 上调 农村 养老金 上涨 五保 供养 补贴 增加',
#  '11 月份 起 这 6 项 资金 开始 下发 请 农民 朋友 互相 转告',
#  '11 月 农民工 工资 上调 农村 养老金 上涨 五保 供养 补贴 增加',
#  '11 月 农民工 工资 上调 农村 养老金 上涨 五保 供养 补贴 增加',
#  '11 月 西安 房价 环比 上涨 0.5 2018 年 西安 房价 会 暴跌 吗',
#  '11 月 西安 房价 环比 上涨 0.5 2018 年 西安 房价 会 暴跌 吗',
#  '11 月 起 农民工 工资 上调 五保 供养 补贴 增加 农村 养老金 上涨',
#  '11 月 起 农村 这 4 类人 建房 每户 可领 补贴 达 2 万 类人 不准 再 建房',
#  '11 月 起 农民工 工资 上调 五保 供养 补贴 增加 农村 养老金 上涨',
#  '11 月 起 农民工 工资 上调 五保 供养 补贴 增加 农村 养老金 上涨',
#  '11 月 起 农民工 工资 上调 农村 养老金 上涨 五保 供养 补贴 增加',
#  '120 亿 计划 泡汤 马云 这次 不得不 听话 支付宝 被迫 关闭 蚂蚁 借 呗',
#  '11 月 起 农民工 工资 上调 五保 供养 补贴 增加 农村 养老金 上涨',
#  '11 月 起 农民工 工资 上调 农村 养老金 上涨 五保 供养 补贴 增加',
#  '11 月 起 农民工 工资 上调 农村 养老金 上涨 五保 供养 补贴 增加',
#  '120 km h 将 成 历史 国内 首条 不 限速 高速公路 即将 开通',
#  '120 亿 计划 泡汤 马云 这次 不得不 听话 支付宝 被迫 关闭 蚂蚁 借 呗',
#  '120 亿 计划 泡汤 马云 这次 不得不 听话 支付宝 被迫 关闭 蚂蚁 借 呗',
#  '120 亿 计划 泡汤 马云 这次 不得不 听话 支付宝 被迫 关闭 蚂蚁 借 呗',
#  '120 亿 计划 泡汤 马云 这次 不得不 听话 支付宝 被迫 关闭 蚂蚁 借 呗',
#  '120 亿 计划 泡汤 马云 这次 不得不 听话 支付宝 被迫 关闭 蚂蚁 借 呗',
#  '12306 数据 泄漏',
#  '120 亿 计划 泡汤 马云 这次 不得不 听话 支付宝 被迫 关闭 蚂蚁 借 呗',
#  '120 岁 老人 的 长寿 秘诀 只用 分钟 人人 都 能 做到',
#  '120 亿 计划 泡汤 马云 这次 不得不 听话 支付宝 被迫 关闭 蚂蚁 借 呗',
#  '12306 数据 泄漏',
#  '120 斤 瘦 到 90 斤 多亏 了 这份 实用 的 减肥 安排表 你 还 在 等 什么',
#  '12306 数据 泄漏',
#  '12306 数据 泄漏',
#  '120 岁 老人 的 长寿 秘诀 只用 分钟 人人 都 能 做到',
#  '12306 数据 泄漏',
#  '12306 数据 泄漏',
#  '12306 数据 泄漏',
#  '12306 数据 泄漏',
#  '12306 数据 泄漏',
#  '12306 数据 泄漏',
#  '12306 数据 泄漏',
#  '12306 数据 泄漏',
#  '12306 数据 泄漏',
#  '12306 数据 泄漏',
#  '12306 数据 泄漏',
#  '12306 数据 泄漏',
#  '12306 数据 泄漏',
#  '12306 数据 泄漏',
#  '12306 数据 泄漏',
#  '12306 数据 泄漏',
#  '125 岁 老人 的 长寿 秘诀 只用 分钟 人人 都 能 做 还 远离 心脏病',
#  '125 斤 瘦 到 95 斤 的 亲身经历 分享 瘦身 秘籍 减肥 从此 不再 难',
#  '125 岁 老人 的 长寿 秘诀 只用 分钟 人人 都 能 做 还 远离 心脏病',
#  '125 斤 瘦 到 95 斤 的 亲身经历 分享 瘦身 秘籍 减肥 从此 不再 难',
#  '128 斤 2 个 月 后 97 斤 有 小蛮 腰 透露 3 个 减肥 成功 的 秘诀',
#  '12 万 买辆 同级 无敌 的 国产 MPV 抢先 实拍 比亚迪 宋 MAX',
#  '12 万 的 价格 百万 级 配置 车长 近 5 米 4 款 新车 5 月 上市',
#  '12 万 就 能 买 国产 霸道 四 驱带 大梁 一 看 车标 都 说 比 哈弗 厉害',
#  '12 万 买辆 同级 无敌 的 国产 MPV 抢先 实拍 比亚迪 宋 MAX',
#  '12 万要 买 国产 SUV 选 这 几量 绝对 没差',
#  '12 万 就 能 买 国产 霸道 四 驱带 大梁 一 看 车标 都 说 比 哈弗 厉害',
#  '12 万要 买 国产 SUV 选 这 几量 绝对 没差',
#  '12 万 还 买 啥 A 级车 都 可以 美系 B 级 变形金刚 完美 逼格 不 后悔',
#  '12 万 还 买 啥 A 级车 都 可以 美系 B 级 变形金刚 完美 逼格 不 后悔',
#  '12 万要 买 国产 SUV 选 这 几量 绝对 没差',
#  '12 万要 买 国产 SUV 选 这 几量 绝对 没差',
#  '12 万 还 买 啥 A 级车 都 可以 美系 B 级 变形金刚 完美 逼格 不 后悔',
#  '12 分 不够 扣 全国 这 几个 地方 将 实施 驾照 加 分制 最 多 可以 有 21 分',
#  '12 万 还 买 啥 A 级车 都 可以 美系 B 级 变形金刚 完美 逼格 不 后悔',
#  '12 万 还 买 啥 A 级车 都 可以 美系 B 级 变形金刚 完美 逼格 不 后悔',
#  '12 号线 西线 年底 开通 这些 房子 房价 将 暴涨',
#  '12 号线 西线 年底 开通 这些 房子 房价 将 暴涨',
#  '12 号线 西线 年底 开通 这些 房子 房价 将 暴涨',
#  '12 城 出手 暂停 投放 新车 共享 单车 玩 不 下去 了',
#  '12 号线 西线 年底 开通 这些 房子 房价 将 暴涨',
#  '12 城 出手 暂停 投放 新车 共享 单车 玩 不 下去 了',
#  '12 号线 西线 年底 开通 这些 房子 房价 将 暴涨',
#  '12 城 出手 暂停 投放 新车 共享 单车 玩 不 下去 了',
#  '12 小时 前 井柏然 倪妮 分手 了 合约 情侣 到期',
#  '12 城 出手 暂停 投放 新车 共享 单车 玩 不 下去 了',
#  '12 城 出手 暂停 投放 新车 共享 单车 玩 不 下去 了',
#  '12 小时 前 井柏然 倪妮 分手 了 合约 情侣 到期',
#  '12 小时 前 井柏然 倪妮 分手 了 合约 情侣 到期',
#  '12 小时 前 井柏然 倪妮 分手 了 合约 情侣 到期',
#  '12 小时 前 井柏然 倪妮 分手 了 合约 情侣 到期',
#  '12 小时 前 井柏然 倪妮 分手 了 合约 情侣 到期',
#  '12 小时 前 井柏然 倪妮 分手 了 合约 情侣 到期',
#  '12 小时 前 井柏然 倪妮 分手 了 合约 情侣 到期',
#  '12 小时 前 井柏然 倪妮 分手 了 合约 情侣 到期',
#  '12 小时 前 井柏然 倪妮 分手 了 合约 情侣 到期',
#  '12 小时 前 井柏然 倪妮 分手 了 合约 情侣 到期',
#  '12 小时 前 井柏然 倪妮 分手 了 合约 情侣 到期',
#  '12 小时 前 井柏然 倪妮 分手 了 合约 情侣 到期',
#  '12 小时 前 井柏然 倪妮 分手 了 合约 情侣 到期',
#  '12 小时 前 井柏然 倪妮 分手 了 合约 情侣 到期',
#  '12 岁 以上 儿童 乘机 须 办理 身份证',
#  '12 岁 以上 儿童 乘机 须 办理 身份证',
#  '12 小时 前 井柏然 倪妮 分手 了 合约 情侣 到期',
#  '12 岁 多多 为何 眼神 越来越 忧郁 黄磊 自 曝 已 开始 担心 她 的 早恋 问题',
#  '12 岁 以上 儿童 乘机 须 办理 身份证',
#  '12 岁 多多 为何 眼神 越来越 忧郁 黄磊 自 曝 已 开始 担心 她 的 早恋 问题',
#  '12 岁 以上 儿童 乘机 须 办理 身份证',
#  '12 岁 多多 为何 眼神 越来越 忧郁 黄磊 自 曝 已 开始 担心 她 的 早恋 问题',
#  '12 岁 多多 为何 眼神 越来越 忧郁 黄磊 自 曝 已 开始 担心 她 的 早恋 问题',
#  '12 岁 多多 为何 眼神 越来越 忧郁 黄磊 自爆 已 开始 担心 他 的 早恋 问题',
#  '12 岁 多多 为何 眼神 越来越 忧郁 黄磊 自 曝 已 开始 担心 她 的 早恋 问题',
#  '12 岁 多多 为何 眼神 越来越 忧郁 黄磊 自爆 已 开始 担心 他 的 早恋 问题',
#  '12 岁 多多 眼神 为何 越来越 忧郁 黄磊 自 曝 已经 开始 担心 她 的 早恋 问题',
#  '12 岁 多多 眼神 为何 越来越 忧郁 黄磊 自 曝 已经 开始 担心 她 早恋 问题',
#  '12 岁 多多 眼神 为何 越来越 忧郁 黄磊 自 曝 已经 开始 担心 她 早恋 问题',
#  '12 岁 天才少年 发明 永动机 离家出走 独自 踏上 神秘 的 旅程',
#  '12 岁 天才少年 发明 永动机 离家出走 独自 踏上 神秘 的 旅程',
#  '12 岁 多多 眼神 为何 越来越 忧郁 黄磊 自 曝 已经 开始 担心 她 早恋 问题',
#  '12 岁 成名 被 骂 最丑 童星 如今 25 岁 0 颈 纹 美 过 杨紫 又 被 质疑 整容',
#  '12 岁 成名 因 丑 被 北影 拒绝 如今 25 岁 美过 杨紫 却 被 质疑 整容',
#  '12 岁 成名 因 丑 被 北影 拒绝 如今 25 岁 美过 杨紫 却 被 质疑 整容',
#  '12 年 义务教育 来 了',
#  '12 年 义务教育 来 了',
#  '12 年 义务教育 来 了',
#  '12 年 义务教育 来 了',
#  '12 岁 成名 因 丑 被 北影 拒绝 如今 25 岁 美过 杨紫 却 被 质疑 整容',
#  '12 岁 成名 因 丑 被 北影 拒绝 如今 25 岁 美过 杨紫 却 被 质疑 整容',
#  '12 岁 成名 因 丑 被 北影 拒绝 如今 25 岁 美过 杨紫 却 被 质疑 整容',
#  '12 年 义务教育 来 了',
#  '12 年前 一张 100 元 纸币 有人 出价 11000 元 卖 还是 不卖',
#  '12 年前 一张 100 元 纸币 有人 出价 11000 元 卖 还是 不卖',
#  '12 年后 复合 为何 王菲 3 次 拒绝 谢霆锋 的 求婚',
#  '12 年后 我国 究竟 会 出现 多少 单身汉 说 出来 吓死人',
#  '12 年后 我国 究竟 会 出现 多少 单身汉 说 出来 吓死人',
#  '12 年 高血压 花 了 数十万 2 个 鸡蛋 顶 10 副 降压药 高血压 不攻自破',
#  '12 日 军情 中 印 军方 高层 边境 秘密会晤',
#  '12 日 军情 中 印 军方 高层 边境 秘密会晤',
#  '12 日 军情 中 印 军方 高层 边境 秘密会晤',
#  '12 年 高血压 花 了 数十万 2 个 鸡蛋 顶 10 副 降压药 高血压 不攻自破',
#  '12 日 军情 中 印 军方 高层 边境 秘密会晤',
#  '12 日 支付宝 提现 收费 告别 免费 你 的 钱 还好 么',
#  '12 日 支付宝 提现 收费 告别 免费 你 的 钱 还好 么',
#  '12 日 支付宝 提现 收费 告别 免费 你 的 钱 还好 么',
#  '12 日 支付宝 提现 收费 告别 免费 你 的 钱 还好 么',
#  '12 日 科技 精选 对于 联想 把 5 G 的 票 投给 高通 华为 微弱 劣势 丢失 了 标准 你 怎么 看',
#  '12 日 科技 精选 对于 联想 把 5 G 的 票 投给 高通 华为 微弱 劣势 丢失 了 标准 你 怎么 看',
#  '12 日 科技 精选 对于 联想 把 5 G 的 票 投给 高通 华为 微弱 劣势 丢失 了 标准 你 怎么 看',
#  '12 日 科技 精选 对于 联想 把 5 G 的 票 投给 高通 华为 微弱 劣势 丢失 了 标准 你 怎么 看',
#  '12 日 科技 精选 对于 联想 把 5 G 的 票 投给 高通 华为 微弱 劣势 丢失 了 标准 你 怎么 看',
#  '12 日 科技 精选 对于 联想 把 5 G 的 票 投给 高通 华为 微弱 劣势 丢失 了 标准 你 怎么 看',
#  '12 日 科技 精选 对于 联想 把 5 G 的 票 投给 高通 华为 微弱 劣势 丢失 了 标准 你 怎么 看',
#  '12 日 科技 精选 对于 联想 把 5 G 的 票 投给 高通 华为 微弱 劣势 丢失 了 标准 你 怎么 看',
#  '12 月 1 号 起 这 14 个 省份 的 农民 有福 了 254.19 亿 福利 你 知道 吗',
#  '12 日 科技 精选 对于 联想 把 5 G 的 票 投给 高通 华为 微弱 劣势 丢失 了 标准 你 怎么 看',
#  '12 月 1 号 起 这 14 个 省份 的 农民 有福 了 254.19 亿 福利 你 知道 吗',
#  '12 月 1 号 起 这 14 个 省份 的 农民 有福 了 254.19 亿 福利 你 知道 吗',
#  '12 月 1 日 开始 部分 农村 地区 将 取消 9 年 义务教育 实行 15 年 免费 教育',
#  '12 月 1 日 开始 部分 农村 地区 将 取消 9 年 义务教育 实行 15 年 免费 教育',
#  '12 月 1 日 起 将 取消 9 年 义务教育 实行 15 年 免费 教育',
#  '12 月 1 日 开始 部分 农村 地区 将 取消 9 年 义务教育 实行 15 年 免费 教育',
#  '12 月 1 日 起 丽水 将 全面 取消 农业 户口 统一 登记 为 居民 户口',
#  '12 月 1 日 起 丽水 将 全面 取消 农业 户口 统一 登记 为 居民 户口',
#  '12 月 1 日 起 将 取消 9 年 义务教育 实行 15 年 免费 教育',
#  '12 月 1 日 起 将 取消 9 年 义务教育 实行 15 年 免费 教育 幼儿园 都 免',
#  '12 月 1 日 起 将 取消 9 年 义务教育 实行 15 年 免费 教育 幼儿园 都 免',
#  '12 月 1 日 起 部分 农村 地区 开始 试点 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 开始 试点 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 开始 试点 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 开始 试点 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 开始 试点 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 开始 试点 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 开始 试点 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 开始 试点 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 开始 试点 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 开始 试点 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 开始 试点 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 实行 15 年 免费 教育 取消 9 年 义务教育',
#  '12 月 1 日 起 部分 农村 地区 实行 15 年 免费 教育 取消 9 年 义务教育',
#  '12 月 1 日 起 部分 农村 地区 开始 试点 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 将 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 开始 试点 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 实行 15 年 免费 教育 取消 9 年 义务教育',
#  '12 月 1 日 起 部分 农村 地区 将 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 实行 15 年 免费 教育 取消 9 年 义务教育',
#  '12 月 1 日 起 部分 农村 地区 将 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 将 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 将 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 将 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 将 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 将 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 将 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 将 取消 义务教育 实行 免费 教育',
#  '12 月 1 日 起 部分 农村 地区 将 取消 义务教育 实行 免费 教育',
#  ...]

# %%
vectorizer = TfidfVectorizer(min_df=1) 
vectorizer.fit_transform(corpus)
# Out:
# <641104x67243 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5064277 stored elements in Compressed Sparse Row format>

# %% [markdown]
# 我们看到，通过训练得到了一个包含**67243** 个标引词的词典，每个新闻标题被转换为一个67243维的TF-IDF 向量表示。
#
# ---
# 好了，就到这儿。
